# %% [markdown]
# ## 83. Remove Duplicates from Sorted List
#
# Given an array nums of size n, return the majority element.
#
# The majority element is the element that appears more than ⌊n / 2⌋ times. You may assume that the majority element always exists in the array.
#
# Submit solution here: https://leetcode.com/problems/majority-element/description/

# %% [markdown]
# ## SQLAlchemy
#
# Some more SQL-Alchemy syntax.
#
# First, let's pull up the code that allowed us to create our `epi_country` and `gdp` objects.
#
# More information on the session object here: https://docs.sqlalchemy.org/en/20/orm/session_basics.html

# %%
from sqlalchemy import create_engine, func
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
import pandas as pd

# postgresql+psycopg2://postgres:@localhost/epi

# the `create_engine` function prepares a connection to the database
# should this info be public? 
engine = create_engine('postgresql+psycopg2://postgres:password@localhost:5434/epi')

# this object will automatically map our db entity into a Python class
Base = automap_base()

# get db into automapper
Base.prepare(engine, reflect=True)

# save classes as variables, prepare classes
epi_country = Base.classes.epi_country
gdp = Base.classes.economic

# query our database (pull data and save into objects)
session = Session(engine)

# %% [markdown]
# We can utilize the `func` object to apply aggregate functions to our queries just like we did with Postgres.
#
# https://docs.sqlalchemy.org/en/14/core/sqlelement.html#sqlalchemy.sql.expression.func
#
# Let's calculate how many rows we have in our tables before pulling.

# %%
session.query(func.count(gdp.country))

# %% [markdown]
# Without the `.all()` function, we return an object instead of a list of tuples.

# %%
session.query(func.count(gdp.country)).all()
# Out:
# [(191,)]

# %% [markdown]
# If we want to return how many times a certain country shows up in our table, we can construct a query similiar to
#
# ```sql
# SELECT country, count(*)
# FROM economic
# GROUP BY country
# ```
#
# via

# %%
session.query(gdp.country, func.count(gdp.country)).group_by(gdp.country).all()
# Out:
# [('Indonesia', 3),
#  ('Switzerland', 4),
#  ('New Zealand', 4),
#  ('Italy', 4),
#  ('Hungary', 4),
#  ("China (People's Republic of)", 3),
#  ('Russia', 4),
#  ('Luxembourg', 4),
#  ('Korea', 4),
#  ('Czech Republic', 4),
#  ('Sweden', 4),
#  ('Norway', 4),
#  ('United Kingdom', 4),
#  ('Netherlands', 4),
#  ('Brazil', 3),
#  ('Austria', 4),
#  ('Australia', 4),
#  ('Ireland', 4),
#  ('Germany', 4),
#  ('G7', 4),
#  ('European Union ? 27 countries (from 01/02/2020)', 4),
#  ('Canada', 4),
#  ('Portugal', 4),
#  ('Finland', 4),
#  ('Colombia', 4),
#  ('Lithuania', 4),
#  ('Slovak Republic', 4),
#  ('Spain', 4),
#  ('Latvia', 4),
#  ('Slovenia', 4),
#  ('Turkiye', 4),
#  ('Greece', 4),
#  ('India', 3),
#  ('Belgium', 4),
#  ('Chile', 4),
#  ('Euro area (19 countries)', 4),
#  ('France', 4),
#  ('Estonia', 4),
#  ('Israel', 4),
#  ('South Africa', 4),
#  ('Mexico', 4),
#  ('OECD - Total', 4),
#  ('Poland', 4),
#  ('Iceland', 4),
#  ('Costa Rica', 4),
#  ('Japan', 4),
#  ('Denmark', 4),
#  ('BRIICS economies - Brazil, Russia, India, Indonesia, China and South Africa', 3),
#  ('United States', 4)]

# %% [markdown]
# We can go further with function chaining in sqlalchemy to create the following:

# %%
session.query(gdp.country, func.count(gdp.country)).group_by(gdp.country).order_by(func.count(gdp.country).desc()).all()
# Out:
# [('United States', 4),
#  ('Switzerland', 4),
#  ('New Zealand', 4),
#  ('Italy', 4),
#  ('Hungary', 4),
#  ('Poland', 4),
#  ('Iceland', 4),
#  ('Costa Rica', 4),
#  ('Japan', 4),
#  ('Denmark', 4),
#  ('Russia', 4),
#  ('Luxembourg', 4),
#  ('Korea', 4),
#  ('Czech Republic', 4),
#  ('Sweden', 4),
#  ('Norway', 4),
#  ('United Kingdom', 4),
#  ('Netherlands', 4),
#  ('Austria', 4),
#  ('Australia', 4),
#  ('Ireland', 4),
#  ('Germany', 4),
#  ('G7', 4),
#  ('European Union ? 27 countries (from 01/02/2020)', 4),
#  ('Canada', 4),
#  ('Portugal', 4),
#  ('Finland', 4),
#  ('Colombia', 4),
#  ('Lithuania', 4),
#  ('Slovak Republic', 4),
#  ('Spain', 4),
#  ('Latvia', 4),
#  ('Slovenia', 4),
#  ('Turkiye', 4),
#  ('Greece', 4),
#  ('Belgium', 4),
#  ('Chile', 4),
#  ('Euro area (19 countries)', 4),
#  ('France', 4),
#  ('Estonia', 4),
#  ('Israel', 4),
#  ('South Africa', 4),
#  ('Mexico', 4),
#  ('OECD - Total', 4),
#  ("China (People's Republic of)", 3),
#  ('Brazil', 3),
#  ('BRIICS economies - Brazil, Russia, India, Indonesia, China and South Africa', 3),
#  ('Indonesia', 3),
#  ('India', 3)]

# %% [markdown]
# Going back to yesterday, however, we can utilize the following code to get every single column available within a table.
#
# We simply place the entire object within the `query` function

# %%
rows = session.query(epi_country)
for row in rows.all():
    print(row)
# Out:
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EE650>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EE5F0>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EE680>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EE6E0>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EE740>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EE770>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EE800>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EE890>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EE920>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EE9B0>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EEA40>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EEAD0>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EEB60>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EEBF0>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EEC80>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EED10>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EEDA0>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EEE30>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EEEC0>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EEF50>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EEFE0>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EF070>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EF100>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EF190>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EF220>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EF2B0>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EF340>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EF3D0>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EF460>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EF4F0>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EF580>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EF610>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EF6A0>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EF730>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EF7C0>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EF850>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EF8E0>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EF970>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EFA00>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EFA90>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EFB20>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EFBB0>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EFC40>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EFCD0>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EFD60>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EFDF0>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EFE80>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EFF10>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218958EFFA0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895940070>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895940100>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895940190>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895940220>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959402B0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895940340>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959403D0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895940460>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959404F0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895940580>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895940610>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959406A0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895940730>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959407C0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895940850>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959408E0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895940970>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895940A00>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895940A90>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895940B20>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895940BB0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895940C40>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895940CD0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895940D60>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895940DF0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895940E80>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895940F10>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895940FA0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895941030>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959410C0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895941150>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959411E0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895941270>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895941300>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895941390>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895941420>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959414B0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895941540>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959415D0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895941660>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959416F0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895941780>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895941810>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959418A0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895941930>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959419C0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895941A50>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895941AE0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895941B70>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895941C00>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895941C90>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895941D20>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895941DB0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895941E40>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895941ED0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895941F60>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895941FF0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895942080>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895942110>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959421A0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895942230>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959422C0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895942350>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959423E0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895942470>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895942500>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895942590>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895942620>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959426B0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895942740>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959427D0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895942860>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959428F0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895942980>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895942A10>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895942AA0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895942B30>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895942BC0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895942C50>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895942CE0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895942D70>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895942E00>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895942E90>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895942F20>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895942FB0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895943040>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959430D0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895943160>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959431F0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895943280>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895943310>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959433A0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895943430>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959434C0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895943550>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959435E0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895943670>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895943700>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895943790>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895943820>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959438B0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895943940>
# <sqlalchemy.ext.automap.epi_country object at 0x00000218959439D0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895943A60>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895943AF0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895943B80>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895943C10>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895943CA0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895943D30>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895943DC0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895943E50>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895943EE0>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895943F70>
# <sqlalchemy.ext.automap.epi_country object at 0x0000021895950040>

# %% [markdown]
# Notice that this gives you each row saved as object. If we would like to get the discrete values saved in each object, we can create another inner-for-loop.

# %%
rows = session.query(epi_country)
for row in rows.all():
    for key in row.__dict__.keys():
        print(row.__dict__[key])
# Out:
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EE620>
# ISL
# 3.41
# 91.5
# 65.45
# Iceland
# False
# 97.37
# Europe
# False
# 100.0
# 90.31
# Western Europe
# False
# 38.36
# 36117.88
# False
# 96.11
# 310997.0
# 93.5
# 68.86
# 352
# 91116.36
# 95.09
# 100.0
# 91.87
# 66.46
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EE5C0>
# CHE
# 193.72
# 89.1
# 70.0
# Switzerland
# True
# 90.96
# Europe
# False
# 100.0
# 73.83
# Western Europe
# False
# 47.84
# 37581.17
# False
# 93.46
# 7550077.0
# 89.1
# 100.0
# 756
# 38975.12
# 92.29
# 100.0
# 85.9
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EE590>
# CRI
# 87.47
# 77.54
# 90.91
# Costa Rica
# False
# 77.62
# Latin America and Caribbean
# False
# 96.03
# 78.55
# Meso America
# False
# 59.94
# 10239.06
# False
# 73.86
# 4462192.6
# 86.4
# 73.4
# 188
# 51014.99
# 82.18
# 100.0
# 90.61
# 99.12
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EE6B0>
# SWE
# 21.19
# 86.86
# 88.11
# Sweden
# False
# 97.37
# Europe
# False
# 100.0
# 70.11
# Western Europe
# False
# 59.22
# 34090.27
# False
# 96.3
# 9148092.0
# 86.0
# 61.04
# 752
# 431704.25
# 92.77
# 100.0
# 79.32
# 66.52
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EE710>
# NOR
# 14.78
# 82.81
# 70.0
# Norway
# False
# 97.37
# Europe
# False
# 100.0
# 65.68
# Western Europe
# False
# 58.14
# 49358.83
# False
# 97.54
# 4709153.0
# 81.1
# 46.63
# 578
# 318523.72
# 90.75
# 100.0
# 71.52
# 72.4
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EE7D0>
# MUS
# 632.51
# 70.31
# 93.01
# Mauritius
# False
# 97.37
# Sub-Saharan Africa
# False
# 96.63
# 72.92
# Western Indian Ocean
# False
# 43.7
# 10667.86
# True
# 74.38
# 1260692.0
# 80.6
# 44.96
# 480
# 1993.16
# 83.66
# 86.45
# 77.51
# 99.53
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EE860>
# FRA
# 112.79
# 82.81
# 84.12
# France
# False
# 97.37
# Europe
# False
# 100.0
# 56.36
# Western Europe
# False
# 41.97
# 31624.73
# False
# 79.9
# 61707072.0
# 78.2
# 67.43
# 250
# 547106.71
# 90.75
# 100.0
# 65.69
# 87.6
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EE8F0>
# AUT
# 99.99
# 86.86
# 84.54
# Austria
# True
# 84.15
# Europe
# False
# 100.0
# 50.07
# Western Europe
# False
# 39.83
# 35536.57
# False
# 97.55
# 8315427.0
# 78.1
# 100.0
# 40
# 83160.64
# 89.47
# 100.0
# 66.8
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EE980>
# CUB
# 101.23
# 74.45
# 83.2
# Cuba
# False
# 97.37
# Latin America and Caribbean
# False
# 91.12
# 66.6
# Caribbean
# False
# 40.66
# 9100.0
# False
# 74.08
# 11257013.26
# 78.1
# 49.63
# 192
# 111198.91
# 84.35
# 100.0
# 71.91
# 94.3
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EEA10>
# COL
# 38.55
# 63.34
# 76.16
# Colombia
# False
# 90.12
# Latin America and Caribbean
# False
# 81.62
# 71.32
# South America
# False
# 47.77
# 8109.03
# False
# 69.3
# 43987000.0
# 76.8
# 82.66
# 170
# 1141177.03
# 74.6
# 96.89
# 78.94
# 88.59
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EEAA0>
# MLT
# 1297.43
# 86.86
# 62.15
# Malta
# False
# 94.74
# Europe
# False
# 100.0
# 59.01
# Western Europe
# False
# 21.76
# 22045.93
# True
# 61.97
# 409197.0
# 76.3
# 75.06
# 470
# 315.39
# 92.12
# 100.0
# 60.55
# 89.27
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EEB30>
# FIN
# 16.68
# 82.81
# 88.98
# Finland
# False
# 97.37
# Europe
# False
# 100.0
# 46.3
# Western Europe
# False
# 55.29
# 33324.14
# False
# 91.7
# 5288720.0
# 74.7
# 68.64
# 246
# 317001.35
# 90.75
# 100.0
# 58.74
# 69.49
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EEBC0>
# SVK
# 110.43
# 70.31
# 82.32
# Slovakia
# True
# 97.37
# Europe
# False
# 100.0
# 45.2
# Central Europe
# False
# 55.82
# 19341.54
# False
# 94.59
# 5397318.0
# 74.5
# 100.0
# 703
# 48874.99
# 84.5
# 100.0
# 64.41
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EEC50>
# GBR
# 246.8
# 80.96
# 79.21
# United Kingdom
# False
# 97.37
# Europe
# False
# 100.0
# 51.82
# Western Europe
# False
# 37.06
# 33716.77
# False
# 77.45
# 61001341.0
# 74.2
# 70.48
# 826
# 247168.89
# 89.82
# 100.0
# 58.66
# 76.25
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EECE0>
# NZL
# 15.94
# 82.81
# 99.18
# New Zealand
# False
# 97.37
# East Asia and the Pacific
# False
# 100.0
# 38.71
# Australia and New Zealand
# False
# 54.62
# 25281.52
# False
# 94.98
# 4228300.0
# 73.4
# 65.73
# 554
# 265334.38
# 90.75
# 100.0
# 55.97
# 86.35
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EED70>
# CHL
# 23.01
# 79.2
# 96.78
# Chile
# False
# 74.4
# Latin America and Caribbean
# False
# 92.32
# 60.74
# South America
# False
# 42.21
# 13087.43
# False
# 59.21
# 16594596.44
# 73.3
# 40.94
# 152
# 721229.34
# 81.28
# 100.0
# 65.4
# 93.62
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EEE00>
# DEU
# 231.07
# 82.81
# 84.76
# Germany
# False
# 97.37
# Europe
# False
# 100.0
# 49.62
# Western Europe
# False
# 40.0
# 33180.73
# True
# 72.4
# 82268357.0
# 73.2
# 100.0
# 276
# 356026.24
# 90.75
# 100.0
# 55.7
# 36.35
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EEE90>
# ITA
# 198.39
# 86.86
# 86.29
# Italy
# False
# 89.75
# Europe
# False
# 100.0
# 47.97
# Western Europe
# False
# 38.94
# 28681.57
# False
# 73.63
# 59374701.0
# 73.1
# 72.37
# 380
# 299286.24
# 90.87
# 100.0
# 55.24
# 69.07
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EEF20>
# PRT
# 116.03
# 79.2
# 81.78
# Portugal
# False
# 93.31
# Europe
# False
# 98.58
# 49.85
# Western Europe
# False
# 38.82
# 21168.74
# False
# 74.65
# 10608335.0
# 73.0
# 57.97
# 620
# 91426.39
# 87.57
# 100.0
# 58.4
# 97.29
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EEFB0>
# JPN
# 343.74
# 86.86
# 67.99
# Japan
# False
# 87.0
# East Asia and the Pacific
# False
# 100.0
# 48.28
# Northeast Asia
# False
# 34.72
# 31689.34
# False
# 82.64
# 127770750.0
# 72.5
# 63.16
# 392
# 371705.29
# 90.18
# 100.0
# 54.9
# 87.63
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EF040>
# LVA
# 35.46
# 59.41
# 87.52
# Latvia
# False
# 94.59
# Europe
# False
# 86.79
# 55.55
# Central Europe
# False
# 75.19
# 16268.67
# False
# 95.27
# 2276100.0
# 72.5
# 76.29
# 428
# 64195.65
# 75.05
# 100.0
# 69.98
# 60.72
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EF0D0>
# CZE
# 131.48
# 75.96
# 83.61
# Czech Republic
# True
# 96.14
# Europe
# False
# 99.44
# 41.91
# Central Europe
# False
# 40.34
# 22818.93
# False
# 79.67
# 10334160.0
# 71.6
# 100.0
# 203
# 78600.63
# 86.87
# 100.0
# 56.37
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EF160>
# ALB
# 110.51
# 65.5
# 54.55
# Albania
# False
# 52.97
# Eastern Europe and Central Asia
# False
# 95.73
# 68.97
# Central Europe
# False
# 49.16
# 6811.38
# False
# 91.24
# 3132458.0
# 71.4
# 77.02
# 8
# 28346.12
# 69.93
# 100.0
# 72.92
# 62.54
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EF1F0>
# PAN
# 44.83
# 70.31
# 100.0
# Panama
# False
# 67.85
# Latin America and Caribbean
# False
# 78.51
# 58.68
# Meso America
# False
# 44.61
# 10756.84
# False
# 88.56
# 3340604.73
# 71.4
# 71.28
# 591
# 74515.22
# 71.75
# 87.17
# 70.99
# 91.46
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EF280>
# ESP
# 88.82
# 84.77
# 78.14
# Spain
# False
# 85.31
# Europe
# False
# 100.0
# 46.11
# Western Europe
# False
# 37.97
# 28536.42
# False
# 69.83
# 44878945.0
# 70.6
# 57.22
# 724
# 505283.96
# 88.71
# 100.0
# 52.52
# 89.8
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EF310>
# BLZ
# 13.64
# 57.61
# 54.55
# Belize
# False
# 92.61
# Latin America and Caribbean
# False
# 62.5
# 63.62
# Meso America
# False
# 50.62
# 6359.44
# False
# 74.44
# 303991.16
# 69.9
# 96.81
# 84
# 22290.39
# 67.58
# 100.0
# 72.28
# 85.83
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EF3A0>
# ATG
# 191.09
# 73.01
# 54.55
# Antigua and Barbuda
# False
# 97.37
# Latin America and Caribbean
# False
# 89.44
# 61.88
# Caribbean
# True
# 36.03
# 19395.86
# True
# 70.87
# 84813.54
# 69.8
# 27.61
# 28
# 443.84
# 83.21
# 100.0
# 56.38
# 75.54
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EF430>
# SGP
# 7743.95
# 89.1
# 97.73
# Singapore
# False
# 78.53
# East Asia and the Pacific
# False
# 100.0
# 48.57
# South East Asia
# False
# 10.72
# 47497.07
# True
# 99.01
# 4588600.0
# 69.6
# 44.24
# 702
# 592.54
# 89.18
# 100.0
# 50.09
# 50.0
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EF4C0>
# SCG
# 78.79
# 69.04
# 48.18
# Serbia and Montenegro
# False
# 100.0
# Eastern Europe and Central Asia
# False
# 94.65
# 55.26
# Central Europe
# False
# 54.23
# -1.0
# True
# 80.56
# 8002520.0
# 69.4
# 24.85
# -1
# 101566.18
# 83.18
# 100.0
# 55.56
# 90.93
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EF550>
# ECU
# 52.05
# 62.31
# 88.29
# Ecuador
# False
# 91.74
# Latin America and Caribbean
# False
# 86.71
# 55.43
# South America
# False
# 58.21
# 7023.13
# False
# 73.79
# 13339580.48
# 69.3
# 82.92
# 218
# 256270.64
# 75.77
# 47.12
# 62.92
# 97.41
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EF5E0>
# PER
# 22.13
# 61.32
# 100.0
# Peru
# False
# 52.25
# Latin America and Caribbean
# False
# 70.49
# 70.2
# South America
# False
# 43.4
# 7241.26
# False
# 74.6
# 28508481.0
# 69.3
# 52.81
# 604
# 1288259.27
# 61.34
# 96.89
# 77.21
# 88.56
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EF670>
# DNK
# 128.55
# 80.96
# 87.45
# Denmark
# False
# 97.37
# Europe
# False
# 100.0
# 46.15
# Western Europe
# False
# 48.3
# 34904.71
# False
# 80.37
# 5461438.0
# 69.2
# 52.71
# 208
# 42484.49
# 89.82
# 100.0
# 48.49
# 36.5
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EF700>
# HUN
# 109.25
# 66.64
# 82.48
# Hungary
# True
# 97.37
# Europe
# False
# 100.0
# 51.34
# Central Europe
# False
# 51.81
# 17900.46
# False
# 67.66
# 10055780.0
# 69.1
# 49.97
# 348
# 92046.39
# 82.66
# 100.0
# 55.57
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EF790>
# SLV
# 301.14
# 61.32
# 88.64
# El Salvador
# False
# 74.57
# Latin America and Caribbean
# False
# 78.35
# 75.73
# Meso America
# False
# 52.06
# 6151.26
# True
# 74.89
# 6106761.0
# 69.1
# 18.01
# 222
# 20278.94
# 68.89
# 47.12
# 69.26
# 88.32
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EF820>
# HRV
# 78.64
# 74.45
# 97.27
# Croatia
# False
# 82.39
# Eastern Europe and Central Asia
# False
# 98.58
# 39.88
# Central Europe
# False
# 44.37
# 16814.92
# False
# 96.25
# 4435982.0
# 68.7
# 67.65
# 191
# 56405.68
# 82.47
# 100.0
# 54.83
# 80.51
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EF8B0>
# DOM
# 202.23
# 55.08
# 69.48
# Dominican Republic
# False
# 95.95
# Latin America and Caribbean
# False
# 83.91
# 56.58
# Caribbean
# False
# 51.69
# 7296.33
# False
# 54.99
# 9725568.98
# 68.4
# 86.06
# 214
# 48092.01
# 72.51
# 100.0
# 64.38
# 88.54
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EF940>
# LTU
# 51.94
# 60.35
# 85.23
# Lithuania
# False
# 97.37
# Europe
# False
# 79.29
# 59.65
# Central Europe
# False
# 62.44
# 16868.68
# False
# 81.92
# 3375618.0
# 68.3
# 46.53
# 440
# 64995.07
# 74.34
# 100.0
# 62.32
# 42.23
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EF9D0>
# NPL
# 202.06
# 36.49
# 79.55
# Nepal
# True
# 42.99
# South Asia
# False
# 49.55
# 96.36
# South Asia
# False
# 57.8
# 992.34
# True
# 69.09
# 28107592.35
# 68.2
# 79.58
# 524
# 139103.09
# 41.38
# 64.68
# 95.09
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EFA60>
# SUR
# 3.62
# 58.5
# 54.55
# Suriname
# False
# 82.94
# Latin America and Caribbean
# False
# 83.0
# 63.57
# South America
# False
# 58.87
# 6544.14
# False
# 69.37
# 510366.0
# 68.2
# 74.31
# 740
# 141113.67
# 70.73
# 100.0
# 65.62
# 60.19
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EFAF0>
# BTN
# 17.78
# 42.49
# 50.0
# Bhutan
# True
# 85.84
# South Asia
# False
# 56.68
# 71.68
# South Asia
# False
# 62.47
# 3922.85
# False
# 71.4
# 676040.0
# 68.0
# 100.0
# 64
# 38028.67
# 56.88
# 100.0
# 79.16
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EFB80>
# LUX
# 185.53
# 82.81
# 57.27
# Luxembourg
# True
# 97.37
# Europe
# False
# 100.0
# 28.15
# Western Europe
# False
# 65.14
# 72783.17
# False
# 85.13
# 479993.0
# 67.8
# 100.0
# 442
# 2587.12
# 90.75
# 100.0
# 44.92
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EFC10>
# DZA
# 14.7
# 61.32
# 74.02
# Algeria
# False
# 63.98
# Middle East and North Africa
# False
# 83.7
# 66.18
# Northern Africa
# True
# 45.43
# 7316.78
# False
# 55.77
# 33852675.6
# 67.4
# 51.89
# 12
# 2302498.08
# 67.58
# 100.0
# 67.25
# 85.59
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EFCA0>
# MEX
# 54.18
# 73.01
# 80.35
# Mexico
# False
# 75.46
# Latin America and Caribbean
# False
# 85.03
# 56.42
# Meso America
# False
# 40.18
# 13307.27
# False
# 59.95
# 105280515.4
# 67.3
# 51.1
# 484
# 1943058.29
# 76.63
# 87.56
# 58.06
# 89.61
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EFD30>
# IRL
# 62.85
# 84.77
# 75.29
# Ireland
# False
# 97.37
# Europe
# False
# 100.0
# 40.36
# Western Europe
# False
# 51.48
# 41036.2
# False
# 95.95
# 4366193.0
# 67.1
# 7.03
# 372
# 69473.98
# 91.73
# 100.0
# 42.48
# 69.5
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EFDC0>
# ROU
# 90.89
# 64.4
# 87.59
# Romania
# False
# 87.95
# Europe
# False
# 73.94
# 50.8
# Central Europe
# False
# 46.11
# 10750.47
# False
# 73.44
# 21546873.0
# 67.0
# 63.55
# 642
# 237056.1
# 72.67
# 100.0
# 61.34
# 94.13
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EFE50>
# CAN
# 3.49
# 86.86
# 89.53
# Canada
# False
# 97.37
# North America
# False
# 100.0
# 37.34
# North America
# False
# 25.27
# 36260.04
# False
# 90.72
# 32976000.0
# 66.4
# 61.91
# 124
# 9458906.77
# 92.77
# 100.0
# 40.1
# 33.77
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EFEE0>
# NLD
# 467.45
# 86.86
# 81.14
# Netherlands
# False
# 83.61
# Europe
# False
# 100.0
# 39.19
# Western Europe
# False
# 38.59
# 36956.14
# True
# 67.36
# 16381137.0
# 66.4
# 80.05
# 528
# 35043.85
# 89.33
# 100.0
# 43.38
# 45.24
# <sqlalchemy.orm.state.InstanceState object at 0x00000218958EFF70>
# MDV
# 1618.21
# 55.9
# 56.82
# Maldives
# False
# 82.89
# South Asia
# False
# 62.34
# 75.46
# South Asia
# False
# 36.26
# 4891.49
# True
# 69.95
# 305340.27
# 65.9
# 0.13
# 462
# 188.69
# 64.26
# 100.0
# 67.62
# 96.37
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895940040>
# FJI
# 45.46
# 63.34
# 95.45
# Fiji
# False
# 76.9
# East Asia and the Pacific
# False
# 38.04
# 60.2
# South Pacific
# False
# 72.72
# 4064.21
# False
# 93.83
# 834278.0
# 65.9
# 16.93
# 242
# 18351.66
# 60.41
# 100.0
# 71.42
# 97.94
# <sqlalchemy.orm.state.InstanceState object at 0x00000218959400D0>
# PHL
# 300.35
# 55.08
# 84.57
# Philippines
# False
# 71.72
# East Asia and the Pacific
# False
# 81.62
# 64.45
# South East Asia
# False
# 51.76
# 3181.65
# True
# 86.41
# 88718185.0
# 65.7
# 64.16
# 608
# 295386.88
# 65.88
# 47.95
# 65.49
# 76.27
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895940160>
# AUS
# 2.75
# 84.77
# 97.19
# Australia
# False
# 97.37
# East Asia and the Pacific
# False
# 100.0
# 27.64
# Australia and New Zealand
# False
# 29.46
# 32734.85
# False
# 57.95
# 21015000.0
# 65.7
# 77.86
# 36
# 7634643.84
# 91.73
# 96.89
# 39.58
# 96.53
# <sqlalchemy.orm.state.InstanceState object at 0x00000218959401F0>
# MAR
# 76.43
# 64.4
# 82.11
# Morocco
# False
# 95.09
# Middle East and North Africa
# False
# 69.63
# 56.64
# Northern Africa
# True
# 65.49
# 3879.7
# False
# 57.11
# 30860594.59
# 65.6
# 25.46
# 504
# 403759.34
# 73.38
# 100.0
# 57.84
# 75.78
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895940280>
# BLR
# 46.87
# 52.74
# 54.55
# Belarus
# True
# 97.37
# Eastern Europe and Central Asia
# False
# 96.07
# 51.57
# Eastern Europe
# False
# 62.6
# 10280.06
# False
# 66.02
# 9702000.0
# 65.4
# 70.13
# 112
# 207012.55
# 74.73
# 100.0
# 56.01
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895940310>
# MYS
# 80.26
# 67.82
# 94.75
# Malaysia
# False
# 93.81
# East Asia and the Pacific
# False
# 95.77
# 42.33
# South East Asia
# False
# 44.72
# 12766.19
# False
# 74.01
# 26549517.75
# 65.0
# 74.07
# 458
# 330798.79
# 81.31
# 89.11
# 48.67
# 52.83
# <sqlalchemy.orm.state.InstanceState object at 0x00000218959403A0>
# SVN
# 99.79
# 77.54
# 65.06
# Slovenia
# False
# 84.82
# Europe
# False
# 100.0
# 41.37
# Central Europe
# False
# 47.13
# 26293.87
# False
# 96.49
# 2018122.0
# 65.0
# 51.14
# 705
# 20223.97
# 84.98
# 100.0
# 44.93
# 50.0
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895940430>
# SYR
# 111.21
# 73.01
# 81.77
# Syria
# False
# 62.62
# Middle East and North Africa
# False
# 86.03
# 60.96
# Mashriq
# False
# 53.78
# 4038.42
# False
# 34.37
# 20503917.0
# 64.6
# 8.48
# 760
# 184365.81
# 73.67
# 100.0
# 55.49
# 85.72
# <sqlalchemy.orm.state.InstanceState object at 0x00000218959404C0>
# EST
# 31.07
# 59.41
# 85.76
# Estonia
# False
# 91.37
# Europe
# False
# 97.19
# 36.0
# Central Europe
# False
# 54.47
# 19327.15
# False
# 89.67
# 1341672.0
# 63.8
# 88.53
# 233
# 43178.85
# 76.85
# 95.37
# 50.76
# 67.88
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895940550>
# LKA
# 303.96
# 41.41
# 83.73
# Sri Lanka
# False
# 23.91
# South Asia
# False
# 76.63
# 79.71
# South Asia
# False
# 53.85
# 4007.59
# True
# 78.77
# 20010000.0
# 63.7
# 73.99
# 144
# 65830.04
# 45.84
# 54.56
# 81.59
# 84.08
# <sqlalchemy.orm.state.InstanceState object at 0x00000218959405E0>
# GEO
# 63.53
# 69.04
# 56.82
# Georgia
# False
# 55.26
# Eastern Europe and Central Asia
# False
# 95.21
# 54.38
# Eastern Europe
# False
# 69.43
# 4402.61
# False
# 57.7
# 4398587.55
# 63.6
# 26.85
# 268
# 69236.14
# 72.14
# 100.0
# 55.15
# 90.47
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895940670>
# PRY
# 15.46
# 65.5
# 97.73
# Paraguay
# True
# 37.93
# Latin America and Caribbean
# False
# 63.34
# 72.48
# South America
# False
# 42.5
# 4186.48
# False
# 56.81
# 6120495.76
# 63.5
# 53.04
# 600
# 395907.51
# 58.07
# 72.01
# 68.96
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895940700>
# USA
# 32.71
# 79.2
# 83.82
# United States of America
# False
# 95.66
# North America
# False
# 99.14
# 29.37
# North America
# False
# 31.59
# 43102.28
# False
# 70.23
# 301290000.0
# 63.5
# 65.92
# 840
# 9210753.38
# 88.3
# 100.0
# 38.65
# 87.57
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895940790>
# BRA
# 22.34
# 58.5
# 90.73
# Brazil
# False
# 90.18
# Latin America and Caribbean
# False
# 79.33
# 46.44
# South America
# False
# 39.31
# 9145.54
# False
# 85.63
# 190119995.0
# 63.4
# 61.31
# 76
# 8511043.6
# 71.63
# 82.42
# 55.19
# 89.71
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895940820>
# POL
# 122.5
# 70.31
# 76.56
# Poland
# False
# 80.9
# Europe
# False
# 79.25
# 45.93
# Central Europe
# False
# 39.44
# 15637.97
# False
# 79.6
# 38120560.0
# 63.1
# 80.44
# 616
# 311195.23
# 75.19
# 100.0
# 51.03
# 47.89
# <sqlalchemy.orm.state.InstanceState object at 0x00000218959408B0>
# VEN
# 30.14
# 67.82
# 56.82
# Venezuela
# False
# 97.37
# Latin America and Caribbean
# False
# 83.52
# 47.24
# South America
# False
# 38.67
# 11479.97
# False
# 56.12
# 27483000.0
# 62.9
# 78.19
# 862
# 911835.87
# 79.13
# 81.34
# 46.67
# 75.28
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895940940>
# BGR
# 68.82
# 65.5
# 95.44
# Bulgaria
# False
# 63.26
# Europe
# False
# 98.58
# 39.92
# Central Europe
# False
# 41.33
# 10569.85
# False
# 68.68
# 7659764.0
# 62.5
# 66.94
# 100
# 111307.14
# 73.21
# 100.0
# 51.85
# 93.2
# <sqlalchemy.orm.state.InstanceState object at 0x00000218959409D0>
# ISR
# 328.19
# 91.5
# 36.8
# Israel
# False
# 85.42
# Middle East and North Africa
# False
# 100.0
# 32.37
# Western Europe
# True
# 38.85
# 24824.21
# False
# 41.01
# 7180100.0
# 62.4
# 72.76
# 376
# 21878.11
# 92.11
# 100.0
# 32.75
# 91.64
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895940A60>
# THA
# 130.4
# 55.9
# 90.01
# Thailand
# False
# 54.48
# East Asia and the Pacific
# False
# 96.03
# 52.97
# South East Asia
# False
# 36.59
# 6982.73
# False
# 77.73
# 66979359.0
# 62.2
# 79.77
# 764
# 513634.82
# 65.58
# 89.85
# 58.73
# 60.13
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895940AF0>
# EGY
# 82.7
# 61.32
# 73.52
# Egypt
# False
# 50.32
# Middle East and North Africa
# False
# 79.2
# 62.12
# Northern Africa
# True
# 40.95
# 4761.74
# False
# 43.94
# 80060540.0
# 62.0
# 59.17
# 818
# 968071.46
# 63.04
# 100.0
# 60.97
# 76.8
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895940B80>
# RUS
# 8.52
# 44.18
# 35.57
# Russia
# False
# 95.89
# Eastern Europe and Central Asia
# False
# 90.12
# 45.28
# Eastern Europe
# False
# 54.63
# 13872.75
# False
# 84.51
# 142100000.0
# 61.2
# 80.26
# 643
# 16679992.73
# 68.59
# 100.0
# 53.83
# 91.94
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895940C10>
# ARG
# 14.44
# 71.63
# 95.45
# Argentina
# False
# 63.21
# Latin America and Caribbean
# False
# 91.5
# 49.58
# South America
# False
# 48.24
# 12501.62
# False
# 72.91
# 39503466.05
# 61.0
# 31.25
# 32
# 2736296.0
# 74.49
# 82.81
# 47.6
# 48.08
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895940CA0>
# GRC
# 84.87
# 82.81
# 67.73
# Greece
# False
# 81.9
# Europe
# False
# 98.88
# 32.34
# Western Europe
# False
# 38.03
# 26928.23
# False
# 78.44
# 11193366.0
# 60.9
# 35.67
# 300
# 131890.98
# 86.6
# 100.0
# 35.13
# 77.56
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895940D30>
# BRN
# 67.14
# 86.86
# 89.09
# Brunei Darussalam
# False
# 71.17
# East Asia and the Pacific
# False
# 100.0
# 25.54
# South East Asia
# False
# 56.65
# 47406.54
# False
# 74.29
# 389252.04
# 60.8
# 76.65
# 96
# 5797.99
# 86.22
# 82.17
# 35.28
# 60.39
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895940DC0>
# MKD
# 82.48
# 69.04
# 67.27
# Macedonia
# True
# 79.47
# Eastern Europe and Central Asia
# False
# 93.83
# 36.53
# Central Europe
# False
# 69.81
# 8420.24
# False
# 79.85
# 2037031.68
# 60.6
# 40.18
# 807
# 24697.07
# 77.85
# 100.0
# 43.41
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895940E50>
# TUN
# 69.15
# 67.82
# 43.9
# Tunisia
# False
# 86.61
# Middle East and North Africa
# False
# 86.41
# 58.83
# Northern Africa
# False
# 45.68
# 7101.78
# False
# 50.64
# 10225400.0
# 60.6
# 9.99
# 788
# 147881.49
# 77.16
# 100.0
# 44.0
# 48.5
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895940EE0>
# DJI
# 39.85
# 29.91
# 86.36
# Djibouti
# False
# 71.41
# Sub-Saharan Africa
# False
# 74.58
# 75.44
# Eastern Africa
# True
# 75.23
# 1938.42
# False
# 48.09
# 832991.99
# 60.5
# 1.73
# 262
# 20903.5
# 51.45
# 100.0
# 69.64
# 61.96
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895940F70>
# ARM
# 108.67
# 62.31
# 92.84
# Armenia
# True
# 68.66
# Eastern Europe and Central Asia
# False
# 93.23
# 49.85
# Eastern Europe
# False
# 61.96
# 5261.32
# False
# 50.52
# 3072450.0
# 60.4
# 55.34
# 51
# 28272.73
# 71.63
# 63.02
# 49.26
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895941000>
# TUR
# 94.97
# 65.5
# 64.13
# Turkey
# False
# 76.13
# Eastern Europe and Central Asia
# False
# 90.68
# 53.62
# Central Europe
# False
# 46.21
# 11967.68
# False
# 62.83
# 73003736.0
# 60.4
# 17.14
# 792
# 768693.62
# 74.45
# 100.0
# 46.34
# 55.63
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895941090>
# IRN
# 44.66
# 61.32
# 82.38
# Iran
# False
# 72.9
# Middle East and North Africa
# False
# 85.29
# 52.56
# South Asia
# True
# 47.3
# 10345.55
# False
# 45.92
# 71021038.87
# 60.0
# 42.32
# 364
# 1590351.27
# 70.21
# 100.0
# 49.72
# 57.33
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895941120>
# KGZ
# 28.25
# 48.51
# 81.47
# Kyrgyzstan
# True
# 77.58
# Eastern Europe and Central Asia
# False
# 86.59
# 56.2
# Central Asia
# False
# 60.31
# 1894.0
# False
# 51.56
# 5234800.0
# 59.7
# 25.77
# 417
# 185317.14
# 65.29
# 100.0
# 54.06
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x00000218
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895942200>
# GHA
# 98.7
# 29.17
# 90.91
# Ghana
# False
# 40.46
# Sub-Saharan Africa
# False
# 32.76
# 64.34
# Western Africa
# False
# 48.06
# 1290.32
# False
# 88.92
# 22870966.0
# 51.3
# 74.7
# 288
# 231729.96
# 32.89
# 51.28
# 69.78
# 87.02
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895942290>
# MMR
# 72.84
# 37.89
# 90.91
# Myanmar
# False
# 22.07
# East Asia and the Pacific
# False
# 72.66
# 64.94
# South East Asia
# False
# 56.33
# 1200.0
# False
# 66.49
# 48782825.36
# 51.3
# 33.75
# 104
# 669707.48
# 42.63
# 73.18
# 59.97
# 50.0
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895942320>
# TJK
# 51.7
# 38.37
# 40.68
# Tajikistan
# True
# 64.37
# Eastern Europe and Central Asia
# False
# 67.06
# 59.18
# Central Asia
# False
# 68.57
# 1658.74
# False
# 44.47
# 6727377.0
# 51.3
# 38.06
# 762
# 130110.95
# 52.04
# 92.45
# 50.53
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x00000218959423B0>
# MOZ
# 27.5
# 20.03
# 24.77
# Mozambique
# False
# 41.13
# Sub-Saharan Africa
# False
# 11.28
# 89.85
# Southern Africa
# False
# 51.56
# 756.81
# False
# 57.4
# 21372202.42
# 51.2
# 60.11
# 508
# 777123.23
# 23.12
# 92.79
# 79.33
# 66.18
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895942440>
# KWT
# 154.29
# 89.1
# 77.73
# Kuwait
# False
# 55.67
# Middle East and North Africa
# True
# 100.0
# 35.05
# Arabian Peninsula
# True
# 33.42
# 45151.77
# False
# 0.0
# 2662966.04
# 51.1
# 17.09
# 414
# 17259.47
# 83.47
# 100.0
# 18.78
# 41.82
# <sqlalchemy.orm.state.InstanceState object at 0x00000218959424D0>
# SLB
# 17.26
# 55.9
# 42.73
# Solomon Islands
# False
# 68.27
# East Asia and the Pacific
# False
# 35.98
# 55.14
# South Pacific
# False
# 87.03
# 2299.8
# False
# 74.37
# 495361.74
# 51.1
# 0.51
# 90
# 28707.41
# 54.01
# 47.12
# 48.19
# 97.61
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895942560>
# ZAF
# 39.3
# 37.42
# 64.25
# South Africa
# False
# 90.21
# Sub-Saharan Africa
# False
# 70.96
# 39.48
# Southern Africa
# False
# 30.36
# 9224.22
# False
# 68.1
# 47850700.0
# 50.8
# 62.39
# 710
# 1217643.11
# 59.0
# 100.0
# 42.57
# 80.05
# <sqlalchemy.orm.state.InstanceState object at 0x00000218959425F0>
# GMB
# 149.06
# 25.72
# 100.0
# Gambia
# False
# 11.8
# Sub-Saharan Africa
# False
# 61.0
# 75.42
# Western Africa
# False
# 51.39
# 1222.45
# False
# 74.32
# 1615510.0
# 50.3
# 16.49
# 270
# 10837.79
# 31.06
# 100.0
# 69.59
# 30.92
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895942680>
# LBY
# 3.82
# 70.31
# 36.82
# Libyan Arab Jamahiriya
# False
# 58.43
# Middle East and North Africa
# False
# 73.32
# 43.47
# Northern Africa
# True
# 49.7
# 13564.96
# False
# 30.34
# 6156487.54
# 50.1
# 2.79
# 434
# 1611363.45
# 68.09
# 100.0
# 32.19
# 90.99
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895942710>
# HND
# 63.38
# 56.74
# 52.27
# Honduras
# False
# 51.55
# Latin America and Caribbean
# False
# 67.13
# 47.56
# Meso America
# False
# 55.89
# 3584.93
# False
# 67.74
# 7103785.59
# 49.9
# 62.25
# 340
# 112078.1
# 58.04
# 30.6
# 41.7
# 82.01
# <sqlalchemy.orm.state.InstanceState object at 0x00000218959427A0>
# UGA
# 147.96
# 15.19
# 58.67
# Uganda
# True
# 50.0
# Sub-Saharan Africa
# False
# 31.37
# 78.62
# Eastern Africa
# False
# 51.49
# 1015.53
# False
# 64.66
# 30637544.0
# 49.8
# 87.5
# 800
# 207069.18
# 27.94
# 44.07
# 71.6
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895942830>
# MDG
# 31.38
# 22.6
# 88.64
# Madagascar
# False
# 36.14
# Sub-Saharan Africa
# False
# 4.93
# 74.65
# Western Indian Ocean
# False
# 69.27
# 931.81
# False
# 58.54
# 18604365.0
# 49.2
# 31.58
# 450
# 592965.42
# 21.57
# 92.47
# 76.77
# 86.05
# <sqlalchemy.orm.state.InstanceState object at 0x00000218959428C0>
# CHN
# 143.32
# 62.31
# 69.05
# China
# False
# 40.07
# East Asia and the Pacific
# False
# 70.01
# 40.18
# Northeast Asia
# False
# 30.19
# 5083.66
# False
# 65.95
# 1318309724.0
# 49.0
# 57.22
# 156
# 9198093.51
# 58.68
# 100.0
# 39.33
# 56.53
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895942950>
# QAT
# 103.67
# 89.1
# 36.82
# Qatar
# False
# 72.57
# Middle East and North Africa
# True
# 100.0
# 27.18
# Arabian Peninsula
# True
# 34.98
# 99100.0
# False
# 14.07
# 1137553.0
# 48.9
# 6.17
# 634
# 10973.25
# 87.69
# 100.0
# 10.08
# 66.05
# <sqlalchemy.orm.state.InstanceState object at 0x00000218959429E0>
# IND
# 350.61
# 39.35
# 35.68
# India
# False
# 37.55
# South Asia
# False
# 50.11
# 60.25
# South Asia
# False
# 37.08
# 2600.13
# True
# 68.35
# 1124786997.0
# 48.3
# 38.65
# 356
# 3208099.12
# 41.59
# 100.0
# 55.1
# 85.95
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895942A70>
# YEM
# 53.91
# 27.75
# 75.45
# Yemen
# False
# 43.92
# Middle East and North Africa
# True
# 40.39
# 76.58
# Arabian Peninsula
# True
# 58.38
# 2199.07
# False
# 1.8
# 22383108.05
# 48.3
# 1.61
# 887
# 415203.04
# 34.95
# 100.0
# 61.68
# 75.18
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895942B00>
# PAK
# 206.9
# 43.04
# 40.23
# Pakistan
# False
# 17.38
# South Asia
# False
# 67.81
# 67.14
# South Asia
# True
# 42.97
# 2357.26
# False
# 48.15
# 162481398.8
# 48.0
# 52.85
# 586
# 785319.81
# 42.82
# 42.7
# 53.11
# 83.89
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895942B90>
# TZA
# 46.32
# 18.16
# 59.09
# Tanzania
# False
# 43.71
# Sub-Saharan Africa
# False
# 23.61
# 66.83
# Southern Africa
# False
# 55.28
# 1118.13
# False
# 77.76
# 41276209.0
# 47.9
# 80.59
# 834
# 891021.57
# 25.91
# 70.71
# 69.89
# 83.35
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895942C20>
# ZWE
# 32.0
# 22.01
# 45.89
# Zimbabwe
# True
# 54.81
# Sub-Saharan Africa
# False
# 53.32
# 61.25
# Southern Africa
# False
# 49.19
# 200.0
# False
# 67.69
# 12449219.0
# 47.8
# 93.75
# 716
# 389053.02
# 38.04
# 57.33
# 57.6
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895942CB0>
# BFA
# 53.59
# 4.94
# 81.0
# Burkina Faso
# True
# 12.04
# Sub-Saharan Africa
# False
# 27.04
# 76.31
# Western Africa
# False
# 58.68
# 1057.53
# False
# 59.9
# 14777431.33
# 47.3
# 100.0
# 854
# 275747.61
# 12.24
# 79.12
# 82.33
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895942D40>
# SDN
# 16.22
# 27.06
# 83.34
# Sudan
# False
# 2.68
# Middle East and North Africa
# False
# 37.66
# 72.94
# Northern Africa
# False
# 51.96
# 1878.62
# False
# 61.84
# 40432296.0
# 47.1
# 29.07
# 736
# 2492385.4
# 23.61
# 79.19
# 70.58
# 89.31
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895942DD0>
# ZMB
# 16.52
# 11.61
# 72.73
# Zambia
# True
# 36.76
# Sub-Saharan Africa
# False
# 36.86
# 66.56
# Southern Africa
# False
# 39.05
# 1211.62
# False
# 70.28
# 12313942.0
# 47.0
# 100.0
# 894
# 745317.51
# 24.21
# 74.36
# 69.8
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895942E60>
# OMN
# 8.96
# 77.54
# 41.26
# Oman
# False
# 52.84
# Middle East and North Africa
# False
# 77.19
# 28.03
# Arabian Peninsula
# True
# 52.83
# 20547.93
# False
# 36.95
# 2726301.0
# 45.9
# 47.09
# 512
# 304189.58
# 71.28
# 100.0
# 20.47
# 45.46
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895942EF0>
# GNB
# 45.18
# 4.43
# 56.82
# Guinea-Bissau
# False
# 16.28
# Sub-Saharan Africa
# False
# 25.33
# 75.4
# Western Africa
# False
# 52.11
# 494.82
# False
# 72.75
# 1541040.0
# 44.7
# 75.02
# 624
# 34105.82
# 12.62
# 88.3
# 76.72
# 76.78
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895942F80>
# CMR
# 39.79
# 17.65
# 56.08
# Cameroon
# False
# 27.78
# Sub-Saharan Africa
# False
# 46.64
# 66.13
# Central Africa
# False
# 47.96
# 2009.37
# False
# 76.43
# 18532798.56
# 44.6
# 70.01
# 120
# 465765.23
# 27.43
# 74.6
# 61.82
# 51.01
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895943010>
# IDN
# 118.89
# 45.36
# 86.7
# Indonesia
# False
# 31.81
# East Asia and the Pacific
# False
# 55.82
# 49.24
# South East Asia
# False
# 41.56
# 3504.21
# False
# 79.91
# 225630065.5
# 44.6
# 63.19
# 360
# 1897811.61
# 44.59
# 18.9
# 44.64
# 70.41
# <sqlalchemy.orm.state.InstanceState object at 0x00000218959430A0>
# RWA
# 388.29
# 5.81
# 59.09
# Rwanda
# True
# 43.07
# Sub-Saharan Africa
# False
# 26.62
# 64.45
# Eastern Africa
# False
# 44.69
# 873.13
# True
# 73.05
# 9454534.0
# 44.6
# 85.03
# 646
# 24348.89
# 20.33
# 100.0
# 68.89
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895943130>
# GIN
# 39.11
# 16.4
# 77.27
# Guinea
# False
# 16.89
# Sub-Saharan Africa
# False
# 28.68
# 69.73
# Western Africa
# False
# 49.25
# 1049.89
# False
# 72.77
# 9615073.0
# 44.4
# 46.31
# 324
# 245860.06
# 19.59
# 86.98
# 69.15
# 71.7
# <sqlalchemy.orm.state.InstanceState object at 0x00000218959431C0>
# BOL
# 8.9
# 41.95
# 59.09
# Bolivia
# True
# 41.78
# Latin America and Caribbean
# False
# 55.94
# 31.36
# South America
# False
# 64.71
# 3790.51
# False
# 84.94
# 9517537.28
# 44.3
# 85.71
# 68
# 1069133.7
# 45.4
# 87.74
# 43.27
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895
# <sqlalchemy.orm.state.InstanceState object at 0x00000218959437F0>
# KHM
# 80.45
# 27.75
# 54.55
# Cambodia
# False
# 30.34
# East Asia and the Pacific
# False
# 29.42
# 56.29
# South East Asia
# False
# 55.66
# 1702.19
# False
# 95.0
# 14446056.47
# 41.7
# 81.73
# 116
# 179559.26
# 28.81
# 48.88
# 54.57
# 50.0
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895943880>
# BWA
# 3.36
# 30.28
# 56.82
# Botswana
# True
# 45.75
# Sub-Saharan Africa
# False
# 66.81
# 37.89
# Southern Africa
# False
# 44.64
# 12659.69
# False
# 50.87
# 1881431.53
# 41.3
# 100.0
# 72
# 559515.8
# 43.28
# 74.94
# 39.34
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895943910>
# IRQ
# -1.0
# 20.31
# 33.84
# Iraq
# False
# 50.98
# Middle East and North Africa
# False
# 66.7
# 64.15
# Mashriq
# True
# 47.67
# 3000.0
# False
# 36.23
# -1.0
# 41.0
# 0.0
# 368
# 426753.71
# 39.57
# 100.0
# 42.42
# 38.35
# <sqlalchemy.orm.state.InstanceState object at 0x00000218959439A0>
# TCD
# 8.66
# 6.71
# 77.03
# Chad
# True
# 5.94
# Sub-Saharan Africa
# False
# 5.17
# 75.43
# Central Africa
# False
# 56.04
# 1388.63
# False
# 55.28
# 10763638.42
# 40.8
# 73.51
# 148
# 1243139.16
# 6.13
# 82.89
# 75.56
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895943A30>
# ARE
# 58.37
# 89.1
# 39.09
# United Arab Emirates
# False
# 48.63
# Middle East and North Africa
# True
# 98.32
# 20.58
# Arabian Peninsula
# True
# 34.0
# 51586.22
# False
# 5.27
# 4364746.28
# 40.7
# 1.17
# 784
# 74776.6
# 81.29
# 100.0
# 0.06
# 50.0
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895943AC0>
# NGA
# 163.66
# 9.17
# 59.09
# Nigeria
# False
# 37.19
# Sub-Saharan Africa
# False
# 15.03
# 75.84
# Western Africa
# False
# 40.6
# 1868.91
# False
# 62.07
# 147982941.2
# 40.2
# 74.67
# 566
# 904234.85
# 17.64
# 22.07
# 62.74
# 65.62
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895943B50>
# BEN
# 72.46
# 16.4
# 99.8
# Benin
# False
# 28.43
# Sub-Saharan Africa
# False
# 30.55
# 54.71
# Western Africa
# False
# 50.3
# 1332.29
# False
# 68.62
# 8393132.0
# 39.6
# 74.2
# 204
# 115828.16
# 22.94
# 22.24
# 56.24
# 91.5
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895943BE0>
# HTI
# 352.98
# 29.54
# 50.0
# Haiti
# False
# 34.82
# Latin America and Caribbean
# False
# 18.34
# 58.37
# Caribbean
# False
# 68.69
# 1092.92
# True
# 64.24
# 9611553.97
# 39.5
# 3.14
# 332
# 27229.68
# 28.06
# 82.89
# 50.93
# 79.72
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895943C70>
# MLI
# 9.88
# 1.35
# 58.71
# Mali
# True
# 0.0
# Sub-Saharan Africa
# False
# 34.65
# 78.39
# Western Africa
# False
# 59.5
# 1022.92
# False
# 73.38
# 12334168.03
# 39.4
# 24.32
# 466
# 1248145.58
# 9.34
# 79.74
# 69.51
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895943D00>
# TKM
# 10.78
# 39.85
# 30.84
# Turkmenistan
# True
# 70.7
# Eastern Europe and Central Asia
# False
# 54.54
# 35.05
# Central Asia
# True
# 70.11
# 5663.02
# False
# 32.08
# 4963331.95
# 38.4
# 30.36
# 795
# 460254.24
# 51.24
# 100.0
# 25.55
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895943D90>
# NER
# 12.27
# 0.0
# 79.55
# Niger
# True
# 0.22
# Sub-Saharan Africa
# False
# 0.0
# 75.4
# Western Africa
# True
# 66.45
# 596.64
# False
# 50.9
# 14195085.1
# 37.6
# 68.89
# 562
# 1157232.49
# 0.06
# 76.39
# 75.08
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895943E20>
# TGO
# 110.0
# 21.15
# 86.36
# Togo
# False
# 35.04
# Sub-Saharan Africa
# False
# 15.27
# 54.58
# Western Africa
# False
# 46.39
# 777.37
# False
# 72.1
# 6300495.0
# 36.4
# 75.85
# 768
# 57276.95
# 23.15
# 0.0
# 49.71
# 82.41
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895943EB0>
# AGO
# 14.02
# 0.0
# 54.55
# Angola
# False
# 43.47
# Sub-Saharan Africa
# False
# 29.7
# 53.85
# Southern Africa
# False
# 40.13
# 4875.36
# False
# 64.76
# 17554585.0
# 36.3
# 58.43
# 24
# 1251895.62
# 18.29
# 94.79
# 54.4
# 86.74
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895943F40>
# MRT
# 3.01
# 25.72
# 54.61
# Mauritania
# False
# 29.56
# Sub-Saharan Africa
# False
# 22.87
# 56.86
# Western Africa
# True
# 74.62
# 1820.22
# False
# 56.07
# 3120980.98
# 33.7
# 20.85
# 478
# 1036904.89
# 25.97
# 18.45
# 41.36
# 68.03
# <sqlalchemy.orm.state.InstanceState object at 0x0000021895943FD0>
# CAF
# 6.97
# 14.03
# 84.09
# Central African Republic
# True
# 29.21
# Sub-Saharan Africa
# False
# 31.97
# 30.95
# Central Africa
# False
# 39.0
# 673.66
# False
# 70.21
# 4343404.86
# 33.3
# 100.0
# 140
# 622868.42
# 22.31
# 97.19
# 44.37
# -1.0
# <sqlalchemy.orm.state.InstanceState object at 0x00000218959500A0>
# SLE
# 74.64
# 0.0
# 54.55
# Sierra Leone
# False
# 25.98
# Sub-Saharan Africa
# False
# 9.54
# 60.74
# Western Africa
# False
# 46.77
# 691.48
# False
# 74.49
# 5420400.0
# 32.1
# 37.08
# 694
# 72617.41
# 8.88
# 78.23
# 55.36
# 73.37

# %% [markdown]
# You will notice that if we attempt an erroneous query, this will actually halt our workflow, and we **must** rollback our query to get it working again.

# %%
# bad query
session.query(gdp.country, func.count(gdp.country)).all()

# rollback
session.rollback()

# %% [markdown]
# We notice that the `economic` table is severly lacking in content. Let's add a few more rows of data to our database.
#
# Namely, we will `INSERT` Haiti's 2010 GDP information into the economic table using our `session` object.
#
# https://docs.sqlalchemy.org/en/20/orm/session_api.html#sqlalchemy.orm.Session.add

# %%
# we first create a new object

haiti = gdp(location="HAI", country="Haiti", subject_code="T_GDP", subject="Gross Domestic Product (GDP); millions", measure_code="VPVOB", measure="USD, constant prices, 2015 PPPs", year=2010, unit_code="USD", unit="US Dollar", 
            power_code_id=6, power_code="Millions", value=11860)
session.add(haiti)

# %% [markdown]
# Just like with Git, our changes are not yet reflected until we commit

# %%
session.commit()

# %% [markdown]
# As it applies to pandas, we can actually convert an entire dataframe into a sql table via the following command.
#
# `data` in this context is a dataframe

# %%
data.to_sql('loan_data', engine)

# %%
# be sure to run this
engine.dispose()
