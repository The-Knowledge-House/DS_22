# %% [markdown]
# ## 136. Single Number
#
# Given a non-empty array of integers nums, every element appears twice except for one. Find that single one.
#
# You must implement a solution with a linear runtime complexity and use only constant extra space.
#
# Example 1:
# ```
# Input: nums = [2,2,1]
# Output: 1
# ```
#
# Example 2:
# ```
# Input: nums = [4,1,2,1,2]
# Output: 4
# ```
#
# Example 3:
# ```
# Input: nums = [1]
# Output: 1
# ```
#
# Submit solution here: https://leetcode.com/problems/single-number/description/

# %% [markdown]
# ## Addl. Pandas Functionality
#
# Before we dive deeper into SQL data manipulation, let’s explore more pandas. Namely:
#
# * How to fix dataframe formatting.
# * How to iterate through a dataframe.
# * How to create new columns.
#
# There are is a seemingly infinite number of ways you can manipulate dataframes, we will just explore some basics that will help us better understand the functionality of pandas.

# %% [markdown]
# ## Formatting
#
# In our previous dataframe we noticed some errors with our columns and the values inside of our dataframe.
#
# * “Substitutions” column had an extraneous space
# * There were two “Netherlands”
#
# Leaving these errors in makes your job harder down the line (technical debt). We should handle these errors immediately.
#
# Firstly, let’s fix our “Substitutions” column.

# %%
import pandas as pd
# load in your dataset located in `data/scorers.csv`
df = pd.read_csv("../data/scorers.csv")

df.columns
# Out:
# Index(['Country', 'League', 'Club', 'Player Names', 'Matches_Played',
#        'Substitution ', 'Mins', 'Goals', 'Shots', 'OnTarget',
#        'Shots Per Avg Match', 'On Target Per Avg Match', 'Year'],
#       dtype='object')

# %%
# this will result in an error!
df["Substitution"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File c:\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Substitution'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\saidmf\Desktop\TKH\DS_22\phase_2\week_6\1_9\sql_intro_notes.ipynb Cell 5 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/saidmf/Desktop/TKH/DS_22/phase_2/week_6/1_9/sql_intro_notes.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> # this will result in an error!
# ----> <a href='vscode-notebook-cell:/c%3A/Users/saidmf/Desktop/TKH/DS_22/phase_2/week_6/1_9/sql_intro_notes.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> df["Substitution"]
#
# File c:\Python310\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File c:\Python310\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Substitution'

# %%
# this fixes my error
df.rename(columns={"Substitution ": "Substitution"}, inplace=True)

# %%
df["Substitution"]
# Out:
# 0      16.0
# 1       0.0
# 2       1.0
# 3       3.0
# 4      10.0
#        ...
# 655     0.0
# 656     2.0
# 657     0.0
# 658     0.0
# 659    11.0
# Name: Substitution, Length: 660, dtype: float64

# %% [markdown]
# Next, let’s deal with the problem of two “Netherlands”, one with a space and one without.

# %%
df.groupby("Country")["Goals"].mean()
# Out:
# Country
#  Netherlands    10.375000
# Brazil          10.204301
# England         13.480000
# France           9.964912
# Germany         12.193548
# Italy           14.097826
# Netherlands      5.800000
# Portugal         7.812500
# Spain           12.820225
# USA             12.972222
# Name: Goals, dtype: float64

# %%
df.groupby("Country")["Goals"].groups.keys()
# Out:
# dict_keys([' Netherlands', 'Brazil', 'England', 'France', 'Germany', 'Italy', 'Netherlands', 'Portugal ', 'Spain', 'USA'])

# %%
df.replace(" Netherlands", "Netherlands", inplace=True)

# check countries again
df.groupby("Country")["Goals"].mean()
# Out:
# Country
# Brazil         10.204301
# England        13.480000
# France          9.964912
# Germany        12.193548
# Italy          14.097826
# Netherlands     7.833333
# Portugal        7.812500
# Spain          12.820225
# USA            12.972222
# Name: Goals, dtype: float64

# %% [markdown]
# ## Iterating through a DataFrame
#
# Sometimes, we utilize previous dataframes to create new dataframes. Sometimes, we must iterate through a dataframe to properly compute measures on collected data.
#
# We accomplish this through the `iterrows()` built-in method, or `itertuples()`.
#
# Leaving these errors in makes your job harder down the line (technical debt). We should handle these errors immediately.

# %%
for index, row in df.iterrows():
    print(row)
# Out:
# Country                              Spain
# League                             La Liga
# Club                                 (BET)
# Player Names               Juanmi Callejon
# Matches_Played                        19.0
# Substitution                          16.0
# Mins                                1849.0
# Goals                                 11.0
# Shots                                 48.0
# OnTarget                              20.0
# Shots Per Avg Match                   2.47
# On Target Per Avg Match               1.03
# Year                                  2016
# Name: 0, dtype: object
# Country                                Spain
# League                               La Liga
# Club                                   (BAR)
# Player Names               Antoine Griezmann
# Matches_Played                          36.0
# Substitution                             0.0
# Mins                                  3129.0
# Goals                                   16.0
# Shots                                   88.0
# OnTarget                                41.0
# Shots Per Avg Match                     2.67
# On Target Per Avg Match                 1.24
# Year                                    2016
# Name: 1, dtype: object
# Country                          Spain
# League                         La Liga
# Club                             (ATL)
# Player Names               Luis Suarez
# Matches_Played                    34.0
# Substitution                       1.0
# Mins                            2940.0
# Goals                             28.0
# Shots                            120.0
# OnTarget                          57.0
# Shots Per Avg Match               3.88
# On Target Per Avg Match           1.84
# Year                              2016
# Name: 2, dtype: object
# Country                           Spain
# League                          La Liga
# Club                              (CAR)
# Player Names               Ruben Castro
# Matches_Played                     32.0
# Substitution                        3.0
# Mins                             2842.0
# Goals                               NaN
# Shots                             117.0
# OnTarget                           42.0
# Shots Per Avg Match                3.91
# On Target Per Avg Match             1.4
# Year                               2016
# Name: 3, dtype: object
# Country                            Spain
# League                           La Liga
# Club                               (VAL)
# Player Names               Kevin Gameiro
# Matches_Played                      21.0
# Substitution                        10.0
# Mins                              1745.0
# Goals                               13.0
# Shots                               50.0
# OnTarget                            23.0
# Shots Per Avg Match                 2.72
# On Target Per Avg Match             1.25
# Year                                2016
# Name: 4, dtype: object
# Country                                Spain
# League                               La Liga
# Club                                   (JUV)
# Player Names               Cristiano Ronaldo
# Matches_Played                          29.0
# Substitution                             0.0
# Mins                                  2634.0
# Goals                                   25.0
# Shots                                  162.0
# OnTarget                                60.0
# Shots Per Avg Match                     5.84
# On Target Per Avg Match                 2.16
# Year                                    2016
# Name: 5, dtype: object
# Country                            Spain
# League                           La Liga
# Club                               (RMA)
# Player Names               Karim Benzema
# Matches_Played                      23.0
# Substitution                         6.0
# Mins                              1967.0
# Goals                               11.0
# Shots                               69.0
# OnTarget                            34.0
# Shots Per Avg Match                 3.33
# On Target Per Avg Match              NaN
# Year                                2016
# Name: 6, dtype: object
# Country                      Spain
# League                     La Liga
# Club                         (PSG)
# Player Names               Neymar
# Matches_Played                30.0
# Substitution                   0.0
# Mins                        2694.0
# Goals                         13.0
# Shots                        105.0
# OnTarget                      42.0
# Shots Per Avg Match            3.7
# On Target Per Avg Match       1.48
# Year                          2016
# Name: 7, dtype: object
# Country                         Spain
# League                        La Liga
# Club                            (CEL)
# Player Names               Iago Aspas
# Matches_Played                   25.0
# Substitution                      7.0
# Mins                           2354.0
# Goals                            19.0
# Shots                            78.0
# OnTarget                         37.0
# Shots Per Avg Match              3.15
# On Target Per Avg Match          1.49
# Year                             2016
# Name: 8, dtype: object
# Country                           Spain
# League                          La Liga
# Club                              (EIB)
# Player Names               Sergi Enrich
# Matches_Played                     31.0
# Substitution                        7.0
# Mins                             2904.0
# Goals                              11.0
# Shots                              64.0
# OnTarget                           26.0
# Shots Per Avg Match                2.09
# On Target Per Avg Match            0.85
# Year                               2016
# Name: 9, dtype: object
# Country                      Spain
# League                     La Liga
# Club                          None
# Player Names               Aduriz
# Matches_Played                27.0
# Substitution                   5.0
# Mins                        2480.0
# Goals                         16.0
# Shots                         85.0
# OnTarget                      45.0
# Shots Per Avg Match           3.26
# On Target Per Avg Match       1.72
# Year                          2016
# Name: 10, dtype: object
# Country                             Spain
# League                            La Liga
# Club                                (HUE)
# Player Names               Sandro Ramlrez
# Matches_Played                       28.0
# Substitution                          2.0
# Mins                               2340.0
# Goals                                14.0
# Shots                                93.0
# OnTarget                             38.0
# Shots Per Avg Match                  3.78
# On Target Per Avg Match              1.54
# Year                                 2016
# Name: 11, dtype: object
# Country                           Spain
# League                          La Liga
# Club                              (BAR)
# Player Names               Lionel Messi
# Matches_Played                     32.0
# Substitution                        2.0
# Mins                             2910.0
# Goals                              37.0
# Shots                             179.0
# OnTarget                           76.0
# Shots Per Avg Match                5.84
# On Target Per Avg Match            2.48
# Year                               2016
# Name: 12, dtype: object
# Country                            Spain
# League                           La Liga
# Club                               (VIL)
# Player Names               Gerard Moreno
# Matches_Played                      37.0
# Substitution                         0.0
# Mins                              3361.0
# Goals                               13.0
# Shots                               82.0
# OnTarget                            32.0
# Shots Per Avg Match                 2.32
# On Target Per Avg Match              0.9
# Year                                2016
# Name: 13, dtype: object
# Country                      Spain
# League                     La Liga
# Club                         (JUV)
# Player Names                Morata
# Matches_Played                14.0
# Substitution                  12.0
# Mins                        1392.0
# Goals                         15.0
# Shots                         55.0
# OnTarget                      30.0
# Shots Per Avg Match           3.75
# On Target Per Avg Match       2.05
# Year                          2016
# Name: 14, dtype: object
# Country                                Spain
# League                               La Liga
# Club                                   (MON)
# Player Names               Wissam Ben Yedder
# Matches_Played                          20.0
# Substitution                            11.0
# Mins                                  1735.0
# Goals                                   11.0
# Shots                                   44.0
# OnTarget                                23.0
# Shots Per Avg Match                     2.41
# On Target Per Avg Match                 1.26
# Year                                    2016
# Name: 15, dtype: object
# Country                           Spain
# League                          La Liga
# Club                              (SOC)
# Player Names               Willian Jose
# Matches_Played                     27.0
# Substitution                        1.0
# Mins                             2102.0
# Goals                              12.0
# Shots                              69.0
# OnTarget                           29.0
# Shots Per Avg Match                3.12
# On Target Per Avg Match            1.31
# Year                               2016
# Name: 16, dtype: object
# Country                      Spain
# League                     La Liga
# Club                        Florin
# Player Names               Andone
# Matches_Played                32.0
# Substitution                   5.0
# Mins                        2984.0
# Goals                         12.0
# Shots                         99.0
# OnTarget                      42.0
# Shots Per Avg Match           3.15
# On Target Per Avg Match       1.34
# Year                          2016
# Name: 17, dtype: object
# Country                             Spain
# League                            La Liga
# Club                                (SOC)
# Player Names               Cedric Bakambu
# Matches_Played                       17.0
# Substitution                          9.0
# Mins                               1633.0
# Goals                                10.0
# Shots                                50.0
# OnTarget                             26.0
# Shots Per Avg Match                  2.91
# On Target Per Avg Match              1.51
# Year                                 2016
# Name: 18, dtype: object
# Country                      Spain
# League                     La Liga
# Club                         (RMA)
# Player Names                  Isco
# Matches_Played                18.0
# Substitution                  12.0
# Mins                        1690.0
# Goals                         10.0
# Shots                         32.0
# OnTarget                      15.0
# Shots Per Avg Match            1.8
# On Target Per Avg Match       0.84
# Year                          2016
# Name: 19, dtype: object
# Country                            Italy
# League                           Serie A
# Club                               (LIV)
# Player Names               Mohamed Salah
# Matches_Played                      29.0
# Substitution                         2.0
# Mins                              2567.0
# Goals                               15.0
# Shots                               80.0
# OnTarget                            50.0
# Shots Per Avg Match                 2.96
# On Target Per Avg Match             1.85
# Year                                2016
# Name: 20, dtype: object
# Country                              Italy
# League                             Serie A
# Club                                 (SAS)
# Player Names               Gregoire Defrel
# Matches_Played                        23.0
# Substitution                           6.0
# Mins                                2054.0
# Goals                                 12.0
# Shots                                 43.0
# OnTarget                              28.0
# Shots Per Avg Match                   1.99
# On Target Per Avg Match                1.3
# Year                                  2016
# Name: 21, dtype: object
# Country                            Italy
# League                           Serie A
# Club                               (LAZ)
# Player Names               Ciro Immobile
# Matches_Played                      35.0
# Substitution                         1.0
# Mins                              3294.0
# Goals                               22.0
# Shots                              136.0
# OnTarget                            98.0
# Shots Per Avg Match                 3.92
# On Target Per Avg Match             2.83
# Year                                2016
# Name: 22, dtype: object
# Country                             Italy
# League                            Serie A
# Club                                (VER)
# Player Names               Nikola Kalinic
# Matches_Played                       26.0
# Substitution                          6.0
# Mins                               2648.0
# Goals                                15.0
# Shots                                90.0
# OnTarget                             61.0
# Shots Per Avg Match                  3.23
# On Target Per Avg Match              2.19
# Year                                 2016
# Name: 23, dtype: object
# Country                            Italy
# League                           Serie A
# Club                               (NAP)
# Player Names               Dries Mertens
# Matches_Played                      28.0
# Substitution                         7.0
# Mins                              2671.0
# Goals                               28.0
# Shots                              148.0
# OnTarget                           102.0
# Shots Per Avg Match                 5.26
# On Target Per Avg Match             3.63
# Year                                2016
# Name: 24, dtype: object
# Country                              Italy
# League                             Serie A
# Club                                 (ATA)
# Player Names               Alejandro Gomez
# Matches_Played                        37.0
# Substitution                           0.0
# Mins                                3247.0
# Goals                                 16.0
# Shots                                117.0
# OnTarget                              75.0
# Shots Per Avg Match                   3.42
# On Target Per Avg Match               2.19
# Year                                  2016
# Name: 25, dtype: object
# Country                            Italy
# League                           Serie A
# Club                               (FIO)
# Player Names               Jose CallejOn
# Matches_Played                      37.0
# Substitution                         0.0
# Mins                              3276.0
# Goals                               14.0
# Shots                               86.0
# OnTarget                            57.0
# Shots Per Avg Match                 2.49
# On Target Per Avg Match             1.65
# Year                                2016
# Name: 26, dtype: object
# Country                          Italy
# League                         Serie A
# Club                             (BEN)
# Player Names               Iago Falque
# Matches_Played                    31.0
# Substitution                       4.0
# Mins                            2633.0
# Goals                              NaN
# Shots                             65.0
# OnTarget                          42.0
# Shots Per Avg Match               2.35
# On Target Per Avg Match           1.52
# Year                              2016
# Name: 27, dtype: object
# Country                               Italy
# League                              Serie A
# Club                                  (CAG)
# Player Names               Giovanni Simeone
# Matches_Played                         29.0
# Substitution                            6.0
# Mins                                 2764.0
# Goals                                   NaN
# Shots                                  76.0
# OnTarget                               35.0
# Shots Per Avg Match                    2.61
# On Target Per Avg Match                 1.2
# Year                                   2016
# Name: 28, dtype: object
# Country                           Italy
# League                          Serie A
# Club                              (PSG)
# Player Names               Mauro Icardi
# Matches_Played                     34.0
# Substitution                        0.0
# Mins                             3188.0
# Goals                              24.0
# Shots                             109.0
# OnTarget                           52.0
# Shots Per Avg Match                3.25
# On Target Per Avg Match            1.55
# Year                               2016
# Name: 29, dtype: object
# Country                               Italy
# League                              Serie A
# Club                                  (CRZ)
# Player Names               Diego Falcinelli
# Matches_Played                         35.0
# Substitution                            1.0
# Mins                                 3308.0
# Goals                                  13.0
# Shots                                  99.0
# OnTarget                               65.0
# Shots Per Avg Match                    2.84
# On Target Per Avg Match                1.87
# Year                                   2016
# Name: 30, dtype: object
# Country                            Italy
# League                           Serie A
# Club                               Cyril
# Player Names               Cyril Thereau
# Matches_Played                      31.0
# Substitution                         2.0
# Mins                              2585.0
# Goals                               12.0
# Shots                               70.0
# OnTarget                            48.0
# Shots Per Avg Match                 2.57
# On Target Per Avg Match             1.76
# Year                                2016
# Name: 31, dtype: object
# Country                         Italy
# League                        Serie A
# Club                            (ROM)
# Player Names               Edin Dzeko
# Matches_Played                   33.0
# Substitution                      4.0
# Mins                           3194.0
# Goals                            29.0
# Shots                           178.0
# OnTarget                         99.0
# Shots Per Avg Match              5.29
# On Target Per Avg Match          2.94
# Year                             2016
# Name: 32, dtype: object
# Country                              Italy
# League                             Serie A
# Club                                 (NAP)
# Player Names               Lorenzo Insigne
# Matches_Played                        35.0
# Substitution                           2.0
# Mins                                3031.0
# Goals                                 18.0
# Shots                                147.0
# OnTarget                              81.0
# Shots Per Avg Match                   4.61
# On Target Per Avg Match               2.54
# Year                                  2016
# Name: 33, dtype: object
# Country                                 Italy
# League                                Serie A
# Club                                    (SAM)
# Player Names               Fabio Quagliarella
# Matches_Played                           35.0
# Substitution                              2.0
# Mins                                   3030.0
# Goals                                    12.0
# Shots                                   112.0
# OnTarget                                 70.0
# Shots Per Avg Match                      3.51
# On Target Per Avg Match                  2.19
# Year                                     2016
# Name: 34, dtype: object
# Country                         Italy
# League                        Serie A
# Club                            Marco
# Player Names               Borriello
# Matches_Played                   30.0
# Substitution                      6.0
# Mins                           2737.0
# Goals                            16.0
# Shots                            81.0
# OnTarget                         51.0
# Shots Per Avg Match              2.81
# On Target Per Avg Match          1.77
# Year                             2016
# Name: 35, dtype: object
# Country                           Italy
# League                          Serie A
# Club                              (VIL)
# Player Names               Carlos Bacca
# Matches_Played                     26.0
# Substitution                        6.0
# Mins                             2228.0
# Goals                              13.0
# Shots                              56.0
# OnTarget                           39.0
# Shots Per Avg Match                2.39
# On Target Per Avg Match            1.66
# Year                               2016
# Name: 36, dtype: object
# Country                              Italy
# League                             Serie A
# Club                                 (IMI)
# Player Names               Gonzalo Higuain
# Matches_Played                        32.0
# Substitution                           6.0
# Mins                                3138.0
# Goals                                 24.0
# Shots                                134.0
# OnTarget                              91.0
# Shots Per Avg Match                   4.06
# On Target Per Avg Match               2.75
# Year                                  2016
# Name: 37, dtype: object
# Country                          Italy
# League                         Serie A
# Club                             (SAM)
# Player Names               Keita Balde
# Matches_Played                    21.0
# Substitution                      10.0
# Mins                            2033.0
# Goals                             16.0
# Shots                             70.0
# OnTarget                          48.0
# Shots Per Avg Match               3.27
# On Target Per Avg Match           2.24
# Year                              2016
# Name: 38, dtype: object
# Country                             Italy
# League                            Serie A
# Club                                (TOR)
# Player Names               Andrea Belotti
# Matches_Played                        NaN
# Substitution                          1.0
# Mins                               3241.0
# Goals                                26.0
# Shots                               130.0
# OnTarget                             78.0
# Shots Per Avg Match                  3.81
# On Target Per Avg Match              2.29
# Year                                 2016
# Name: 39, dtype: object
# Country                        Germany
# League                      Bundesliga
# Club                             (HKI)
# Player Names               Fin Bartels
# Matches_Played                     NaN
# Substitution                       8.0
# Mins                            2315.0
# Goals                              8.0
# Shots                             42.0
# OnTarget                          29.0
# Shots Per Avg Match               1.72
# On Target Per Avg Match           1.19
# Year                              2016
# Name: 40, dtype: object
# Country                        Germany
# League                      Bundesliga
# Club                             (BMG)
# Player Names               Lars Stindl
# Matches_Played                     NaN
# Substitution                       1.0
# Mins                            2673.0
# Goals                             11.0
# Shots                             68.0
# OnTarget                          50.0
# Shots Per Avg Match               2.42
# On Target Per Avg Match           1.78
# Year                              2016
# Name: 41, dtype: object
# Country                         Germany
# League                       Bundesliga
# Club                              (BAY)
# Player Names               Serge Gnabry
# Matches_Played                      NaN
# Substitution                        4.0
# Mins                             2028.0
# Goals                              11.0
# Shots                              62.0
# OnTarget                           33.0
# Shots Per Avg Match                 2.9
# On Target Per Avg Match            1.55
# Year                               2016
# Name: 42, dtype: object
# Country                       Germany
# League                     Bundesliga
# Club                           Sandro
# Player Names                  Wagner
# Matches_Played                   30.0
# Substitution                      1.0
# Mins                           2695.0
# Goals                            11.0
# Shots                            65.0
# OnTarget                         35.0
# Shots Per Avg Match              2.29
# On Target Per Avg Match          1.23
# Year                             2016
# Name: 43, dtype: object
# Country                            Germany
# League                          Bundesliga
# Club                                 (HOF)
# Player Names               Andrej Kramaric
# Matches_Played                        28.0
# Substitution                           6.0
# Mins                                2449.0
# Goals                                 15.0
# Shots                                 99.0
# OnTarget                              60.0
# Shots Per Avg Match                   3.84
# On Target Per Avg Match               2.33
# Year                                  2016
# Name: 44, dtype: object
# Country                                  Germany
# League                                Bundesliga
# Club                                       (FCA)
# Player Names               Florian Niederlechner
# Matches_Played                              29.0
# Substitution                                 5.0
# Mins                                      2477.0
# Goals                                       11.0
# Shots                                       79.0
# OnTarget                                    56.0
# Shots Per Avg Match                         3.03
# On Target Per Avg Match                     2.15
# Year                                        2016
# Name: 45, dtype: object
# Country                               Germany
# League                             Bundesliga
# Club                                    (BAY)
# Player Names               Robert Lewandowski
# Matches_Played                           31.0
# Substitution                              2.0
# Mins                                   2871.0
# Goals                                    30.0
# Shots                                   143.0
# OnTarget                                 86.0
# Shots Per Avg Match                      4.73
# On Target Per Avg Match                  2.85
# Year                                     2016
# Name: 46, dtype: object
# Country                          Germany
# League                        Bundesliga
# Club                               (RBL)
# Player Names               Emil Forsberg
# Matches_Played                      27.0
# Substitution                         3.0
# Mins                              2420.0
# Goals                                8.0
# Shots                               49.0
# OnTarget                            32.0
# Shots Per Avg Match                 1.92
# On Target Per Avg Match             1.26
# Year                                2016
# Name: 47, dtype: object
# Country                        Germany
# League                      Bundesliga
# Club                             (CHE)
# Player Names               Timo Werner
# Matches_Played                    28.0
# Substitution                       3.0
# Mins                            2496.0
# Goals                             21.0
# Shots                             74.0
# OnTarget                          50.0
# Shots Per Avg Match               2.82
# On Target Per Avg Match            1.9
# Year                              2016
# Name: 48, dtype: object
# Country                          Germany
# League                        Bundesliga
# Club                               (SCF)
# Player Names               Nils Petersen
# Matches_Played                       7.0
# Substitution                        26.0
# Mins                              1351.0
# Goals                               10.0
# Shots                               52.0
# OnTarget                            33.0
# Shots Per Avg Match                 3.66
# On Target Per Avg Match             2.32
# Year                                2016
# Name: 49, dtype: object
# Country                           Germany
# League                         Bundesliga
# Club                                (SCH)
# Player Names               Vedad Ibisevic
# Matches_Played                       32.0
# Substitution                          0.0
# Mins                               2772.0
# Goals                                12.0
# Shots                                72.0
# OnTarget                             46.0
# Shots Per Avg Match                  2.47
# On Target Per Avg Match              1.58
# Year                                 2016
# Name: 50, dtype: object
# Country                        Germany
# League                      Bundesliga
# Club                              None
# Player Names               Mario Gomez
# Matches_Played                    32.0
# Substitution                       1.0
# Mins                            2950.0
# Goals                             16.0
# Shots                             84.0
# OnTarget                          45.0
# Shots Per Avg Match               2.71
# On Target Per Avg Match           1.45
# Year                              2016
# Name: 51, dtype: object
# Country                               Germany
# League                             Bundesliga
# Club                                    (WOB)
# Player Names               Maximilian Philipp
# Matches_Played                           23.0
# Substitution                              2.0
# Mins                                   2000.0
# Goals                                     9.0
# Shots                                    53.0
# OnTarget                                 34.0
# Shots Per Avg Match                      2.52
# On Target Per Avg Match                  1.62
# Year                                     2016
# Name: 52, dtype: object
# Country                         Germany
# League                       Bundesliga
# Club                              (MAI)
# Player Names               Adam Szalai
# Matches_Played                      7.0
# Substitution                       15.0
# Mins                              833.0
# Goals                               8.0
# Shots                              18.0
# OnTarget                           15.0
# Shots Per Avg Match                2.05
# On Target Per Avg Match            1.71
# Year                               2016
# Name: 53, dtype: object
# Country                                      Germany
# League                                    Bundesliga
# Club                                           (ARS)
# Player Names               Pierre-Emerick Aubameyang
# Matches_Played                                  31.0
# Substitution                                     1.0
# Mins                                          2894.0
# Goals                                           31.0
# Shots                                          116.0
# OnTarget                                        78.0
# Shots Per Avg Match                             3.81
# On Target Per Avg Match                         2.56
# Year                                            2016
# Name: 54, dtype: object
# Country                              Germany
# League                            Bundesliga
# Club                                   (STP)
# Player Names               Guido Burgstaller
# Matches_Played                          17.0
# Substitution                             1.0
# Mins                                  1494.0
# Goals                                    9.0
# Shots                                   45.0
# OnTarget                                24.0
# Shots Per Avg Match                     2.86
# On Target Per Avg Match                 1.53
# Year                                    2016
# Name: 55, dtype: object
# Country                       Germany
# League                     Bundesliga
# Club                            (UNB)
# Player Names                Max Kruse
# Matches_Played                   23.0
# Substitution                      0.0
# Mins                           2121.0
# Goals                            15.0
# Shots                            41.0
# OnTarget                         28.0
# Shots Per Avg Match              1.84
# On Target Per Avg Match          1.25
# Year                             2016
# Name: 56, dtype: object
# Country                        Germany
# League                      Bundesliga
# Club                             (LAG)
# Player Names               Chicharito
# Matches_Played                    20.0
# Substitution                       6.0
# Mins                            1895.0
# Goals                              NaN
# Shots                             52.0
# OnTarget                          30.0
# Shots Per Avg Match               2.61
# On Target Per Avg Match            1.5
# Year                              2016
# Name: 57, dtype: object
# Country                            Germany
# League                          Bundesliga
# Club                                 (KOL)
# Player Names               Anthony Modeste
# Matches_Played                        34.0
# Substitution                           0.0
# Mins                                3075.0
# Goals                                 25.0
# Shots                                101.0
# OnTarget                              53.0
# Shots Per Avg Match                   3.12
# On Target Per Avg Match               1.64
# Year                                  2016
# Name: 58, dtype: object
# Country                         Germany
# League                       Bundesliga
# Club                              (GRO)
# Player Names               Arjen Robben
# Matches_Played                     21.0
# Substitution                        5.0
# Mins                             1882.0
# Goals                              13.0
# Shots                              83.0
# OnTarget                           52.0
# Shots Per Avg Match                4.19
# On Target Per Avg Match            2.62
# Year                               2016
# Name: 59, dtype: object
# Country                           England
# League                     Premier League
# Club                                (INT)
# Player Names               Alexis Sanchez
# Matches_Played                       36.0
# Substitution                          2.0
# Mins                               3385.0
# Goals                                24.0
# Shots                               129.0
# OnTarget                             49.0
# Shots Per Avg Match                  3.62
# On Target Per Avg Match              1.38
# Year                                 2016
# Name: 60, dtype: object
# Country                           England
# League                     Premier League
# Club                                (INT)
# Player Names                Romelu Lukaku
# Matches_Played                       36.0
# Substitution                          1.0
# Mins                               3448.0
# Goals                                25.0
# Shots                               110.0
# OnTarget                             53.0
# Shots Per Avg Match                  3.03
# On Target Per Avg Match              1.46
# Year                                 2016
# Name: 61, dtype: object
# Country                           England
# League                     Premier League
# Club                                (TOT)
# Player Names                   Harry Kane
# Matches_Played                       29.0
# Substitution                          1.0
# Mins                               2636.0
# Goals                                29.0
# Shots                               110.0
# OnTarget                             58.0
# Shots Per Avg Match                  3.96
# On Target Per Avg Match              2.09
# Year                                 2016
# Name: 62, dtype: object
# Country                           England
# League                     Premier League
# Club                                (LEI)
# Player Names                  Jamie Vardy
# Matches_Played                       33.0
# Substitution                          2.0
# Mins                               2938.0
# Goals                                13.0
# Shots                                54.0
# OnTarget                             26.0
# Shots Per Avg Match                  1.75
# On Target Per Avg Match              0.84
# Year                                 2016
# Name: 63, dtype: object
# Country                              England
# League                        Premier League
# Club                                   (CRY)
# Player Names               Christian Benteke
# Matches_Played                          36.0
# Substitution                             0.0
# Mins                                  3299.0
# Goals                                   15.0
# Shots                                  105.0
# OnTarget                                38.0
# Shots Per Avg Match                     3.02
# On Target Per Avg Match                 1.09
# Year                                    2016
# Name: 64, dtype: object
# Country                           England
# League                     Premier League
# Club                                (ROM)
# Player Names                   Pedro None
# Matches_Played                       26.0
# Substitution                          9.0
# Mins                               2250.0
# Goals                                10.0
# Shots                                59.0
# OnTarget                             17.0
# Shots Per Avg Match                  2.49
# On Target Per Avg Match              0.72
# Year                                 2016
# Name: 65, dtype: object
# Country                           England
# League                     Premier League
# Club                                (RMA)
# Player Names                  Eden Hazard
# Matches_Played                       36.0
# Substitution                          0.0
# Mins                               3101.0
# Goals                                16.0
# Shots                                77.0
# OnTarget                             32.0
# Shots Per Avg Match                  2.36
# On Target Per Avg Match              0.98
# Year                                 2016
# Name: 66, dtype: object
# Country                            England
# League                      Premier League
# Club                                 (LIV)
# Player Names               Roberto Firmino
# Matches_Played                        34.0
# Substitution                           1.0
# Mins                                3228.0
# Goals                                 11.0
# Shots                                104.0
# OnTarget                              43.0
# Shots Per Avg Match                   3.06
# On Target Per Avg Match               1.27
# Year                                  2016
# Name: 67, dtype: object
# Country                           England
# League                     Premier League
# Club                                (LIV)
# Player Names                   Sadio Mane
# Matches_Played                       26.0
# Substitution                          1.0
# Mins                               2347.0
# Goals                                13.0
# Shots                                58.0
# OnTarget                             24.0
# Shots Per Avg Match                  2.35
# On Target Per Avg Match              0.97
# Year                                 2016
# Name: 68, dtype: object
# Country                              England
# League                        Premier League
# Club                                   (BAR)
# Player Names               Philippe Coutinho
# Matches_Played                          28.0
# Substitution                             3.0
# Mins                                  2327.0
# Goals                                   13.0
# Shots                                  107.0
# OnTarget                                36.0
# Shots Per Avg Match                     4.37
# On Target Per Avg Match                 1.47
# Year                                    2016
# Name: 69, dtype: object
# Country                           England
# League                     Premier League
# Club                                (ATL)
# Player Names                  Diego Costa
# Matches_Played                       35.0
# Substitution                          0.0
# Mins                               3232.0
# Goals                                20.0
# Shots                               111.0
# OnTarget                             41.0
# Shots Per Avg Match                  3.26
# On Target Per Avg Match              1.21
# Year                                 2016
# Name: 70, dtype: object
# Country                           England
# League                     Premier League
# Club                                (TOT)
# Player Names                    Dele Alli
# Matches_Played                       35.0
# Substitution                          2.0
# Mins                               3182.0
# Goals                                 NaN
# Shots                                95.0
# OnTarget                             43.0
# Shots Per Avg Match                  2.84
# On Target Per Avg Match              1.28
# Year                                 2016
# Name: 71, dtype: object
# Country                           England
# League                     Premier League
# Club                                (MNC)
# Player Names                Sergio Aguero
# Matches_Played                       25.0
# Substitution                          6.0
# Mins                               2444.0
# Goals                                21.0
# Shots                               139.0
# OnTarget                             51.0
# Shots Per Avg Match                   5.4
# On Target Per Avg Match              1.98
# Year                                 2016
# Name: 72, dtype: object
# Country                           England
# League                     Premier League
# Club                                (RAN)
# Player Names                Jermain Defoe
# Matches_Played                       37.0
# Substitution                          0.0
# Mins                               3511.0
# Goals                                15.0
# Shots                                99.0
# OnTarget                              NaN
# Shots Per Avg Match                  2.68
# On Target Per Avg Match              0.84
# Year                                 2016
# Name: 73, dtype: object
# Country                              England
# League                        Premier League
# Club                                   (NAP)
# Player Names               Fernando Llorente
# Matches_Played                          28.0
# Substitution                             5.0
# Mins                                  2562.0
# Goals                                   15.0
# Shots                                   52.0
# OnTarget                                25.0
# Shots Per Avg Match                     1.93
# On Target Per Avg Match                 0.93
# Year                                    2016
# Name: 74, dtype: object
# Country                            England
# League                      Premier League
# Club                                 (WHU)
# Player Names               Michail Antonio
# Matches_Played                        29.0
# Substitution                           0.0
# Mins                                2493.0
# Goals                                 11.0
# Shots                                 79.0
# OnTarget                              25.0
# Shots Per Avg Match                   3.01
# On Target Per Avg Match               0.95
# Year                                  2016
# Name: 75, dtype: object
# Country                               England
# League                         Premier League
# Club                                    (ACM)
# Player Names               Zlatan Ibrahimovic
# Matches_Played                           27.0
# Substitution                              1.0
# Mins                                   2578.0
# Goals                                    17.0
# Shots                                   115.0
# OnTarget                                 45.0
# Shots Per Avg Match                      4.24
# On Target Per Avg Match                  1.66
# Year                                     2016
# Name: 76, dtype: object
# Country                           England
# League                     Premier League
# Club                                (CHE)
# Player Names               Olivier Giroud
# Matches_Played                       11.0
# Substitution                         18.0
# Mins                               1311.0
# Goals                                12.0
# Shots                                39.0
# OnTarget                             20.0
# Shots Per Avg Match                  2.83
# On Target Per Avg Match              1.45
# Year                                 2016
# Name: 77, dtype: object
# Country                           England
# League                     Premier League
# Club                                (TOT)
# Player Names                Son Heung-Min
# Matches_Played                       23.0
# Substitution                         11.0
# Mins                               2174.0
# Goals                                14.0
# Shots                                80.0
# OnTarget                             33.0
# Shots Per Avg Match                   3.5
# On Target Per Avg Match              1.44
# Year                                 2016
# Name: 78, dtype: object
# Country                           England
# League                     Premier League
# Club                                (BOU)
# Player Names                  Joshua King
# Matches_Played                       31.0
# Substitution                          5.0
# Mins                               2856.0
# Goals                                16.0
# Shots                                67.0
# OnTarget                             29.0
# Shots Per Avg Match                  2.23
# On Target Per Avg Match              0.96
# Year                                 2016
# Name: 79, dtype: object
# Country                                            Brazil
# League                     Campeonato Brasileiro SÃ©rie A
# Club                                                (GRE)
# Player Names                                  Diego Souza
# Matches_Played                                       34.0
# Substitution                                          0.0
# Mins                                               2981.0
# Goals                                                14.0
# Shots                                                86.0
# OnTarget                                             35.0
# Shots Per Avg Match                                  2.74
# On Target Per Avg Match                              1.12
# Year                                                 2016
# Name: 80, dtype: object
# Country                                            Brazil
# League                     Campeonato Brasileiro SÃ©rie A
# Club                                                (SAP)
# Player Names                                       Pablo
# Matches_Played                                       30.0
# Substitution                                          3.0
# Mins                                               2757.0
# Goals                                                 9.0
# Shots                                                63.0
# OnTarget                                             24.0
# Shots Per Avg Match                                  2.17
# On Target Per Avg Match                              0.83
# Year                                                 2016
# Name: 81, dtype: object
# Country                                            Brazil
# League                     Campeonato Brasileiro SÃ©rie A
# Club                                                 None
# Player Names                                     Robinho
# Matches_Played                                       26.0
# Substitution                                          4.0
# Mins                                               2234.0
# Goals                                                12.0
# Shots                                                49.0
# OnTarget                                             22.0
# Shots Per Avg Match                                  2.08
# On Target Per Avg Match                              0.94
# Year                                                 2016
# Name: 82, dtype: object
# Country                                            Brazil
# League                     Campeonato Brasileiro SÃ©rie A
# Club                                                 None
# Player Names                                      Kempes
# Matches_Played                                       19.0
# Substitution                                          7.0
# Mins                                               1684.0
# Goals                                                 9.0
# Shots                                                44.0
# OnTarget                                             21.0
# ...
# Player Names                                  Alerrandro
# Matches_Played                                       10.0
# Substitution                                          NaN
# Mins                                                861.0
# Goals                                                 NaN
# Shots                                                24.0
# OnTarget                                             11.0
# Shots Per Avg Match                                  2.65
# On Target Per Avg Match                              1.21
# Year                                                 2020
# Name: 634, dtype: object
# Country                                            Brazil
# League                     Campeonato Brasileiro SÃ©rie A
# Club                                                (FOR)
# Player Names                          Wellington Paulista
# Matches_Played                                       13.0
# Substitution                                          NaN
# Mins                                               1208.0
# Goals                                                 6.0
# Shots                                                24.0
# OnTarget                                             12.0
# Shots Per Avg Match                                  1.89
# On Target Per Avg Match                              0.94
# Year                                                 2020
# Name: 635, dtype: object
# Country                                            Brazil
# League                     Campeonato Brasileiro SÃ©rie A
# Club                                                (RBB)
# Player Names                                   Claudinho
# Matches_Played                                       19.0
# Substitution                                          NaN
# Mins                                               1657.0
# Goals                                                 NaN
# Shots                                                53.0
# OnTarget                                             19.0
# Shots Per Avg Match                                  3.04
# On Target Per Avg Match                              1.09
# Year                                                 2020
# Name: 636, dtype: object
# Country                                            Brazil
# League                     Campeonato Brasileiro SÃ©rie A
# Club                                                (CFC)
# Player Names                                       Robson
# Matches_Played                                       22.0
# Substitution                                          NaN
# Mins                                               1937.0
# Goals                                                 6.0
# Shots                                                53.0
# OnTarget                                             17.0
# Shots Per Avg Match                                   2.6
# On Target Per Avg Match                              0.83
# Year                                                 2020
# Name: 637, dtype: object
# Country                                            Brazil
# League                     Campeonato Brasileiro SÃ©rie A
# Club                                                (FLA)
# Player Names                                       Pedro
# Matches_Played                                       12.0
# Substitution                                          6.0
# Mins                                               1207.0
# Goals                                                 NaN
# Shots                                                46.0
# OnTarget                                             25.0
# Shots Per Avg Match                                  3.62
# On Target Per Avg Match                              1.97
# Year                                                 2020
# Name: 638, dtype: object
# Country                                            Brazil
# League                     Campeonato Brasileiro SÃ©rie A
# Club                                                (CAP)
# Player Names                                Renato Kayzer
# Matches_Played                                       17.0
# Substitution                                          1.0
# Mins                                               1639.0
# Goals                                                 7.0
# Shots                                                46.0
# OnTarget                                             21.0
# Shots Per Avg Match                                  2.67
# On Target Per Avg Match                              1.22
# Year                                                 2020
# Name: 639, dtype: object
# Country                          Netherlands
# League                            Eredivisie
# Club                                   (MNU)
# Player Names               Donny van de Beek
# Matches_Played                          22.0
# Substitution                             1.0
# Mins                                  2023.0
# Goals                                    8.0
# Shots                                   44.0
# OnTarget                                16.0
# Shots Per Avg Match                     2.07
# On Target Per Avg Match                 0.75
# Year                                    2020
# Name: 640, dtype: object
# Country                         Netherlands
# League                           Eredivisie
# Club                                  (AZA)
# Player Names               Teun Koopmeiners
# Matches_Played                         25.0
# Substitution                            0.0
# Mins                                 2336.0
# Goals                                  11.0
# Shots                                  35.0
# OnTarget                               18.0
# Shots Per Avg Match                    1.42
# On Target Per Avg Match                0.73
# Year                                   2020
# Name: 641, dtype: object
# Country                       Netherlands
# League                         Eredivisie
# Club                                Aitor
# Player Names               Cantalapiedra
# Matches_Played                       21.0
# Substitution                          0.0
# Mins                               1933.0
# Goals                                 7.0
# Shots                                58.0
# OnTarget                             23.0
# Shots Per Avg Match                  2.85
# On Target Per Avg Match              1.13
# Year                                 2020
# Name: 642, dtype: object
# Country                      Netherlands
# League                        Eredivisie
# Club                               (FEY)
# Player Names               Bryan Linssen
# Matches_Played                      25.0
# Substitution                         0.0
# Mins                              2256.0
# Goals                               14.0
# Shots                               92.0
# OnTarget                            39.0
# Shots Per Avg Match                 3.87
# On Target Per Avg Match             1.64
# Year                                2020
# Name: 643, dtype: object
# Country                     Netherlands
# League                       Eredivisie
# Club                                Tim
# Player Names                    Matavz
# Matches_Played                     24.0
# Substitution                        1.0
# Mins                             2157.0
# Goals                              12.0
# Shots                              55.0
# OnTarget                           28.0
# Shots Per Avg Match                2.42
# On Target Per Avg Match            1.23
# Year                               2020
# Name: 644, dtype: object
# Country                        Netherlands
# League                          Eredivisie
# Club                                 (SEV)
# Player Names               Oussama Idrissi
# Matches_Played                        25.0
# Substitution                           0.0
# Mins                                2047.0
# Goals                                 13.0
# Shots                                 67.0
# OnTarget                              34.0
# Shots Per Avg Match                   3.11
# On Target Per Avg Match               1.58
# Year                                  2020
# Name: 645, dtype: object
# Country                     Netherlands
# League                       Eredivisie
# Club                              (AJA)
# Player Names                Dusan Tadic
# Matches_Played                     25.0
# Substitution                        0.0
# Mins                             2287.0
# Goals                              11.0
# Shots                              63.0
# OnTarget                           26.0
# Shots Per Avg Match                2.62
# On Target Per Avg Match            1.08
# Year                               2020
# Name: 646, dtype: object
# Country                        Netherlands
# League                          Eredivisie
# Club                                 (FEY)
# Player Names               Steven Berghuis
# Matches_Played                        24.0
# Substitution                           0.0
# Mins                                2226.0
# Goals                                  NaN
# Shots                                 89.0
# OnTarget                              44.0
# Shots Per Avg Match                    3.8
# On Target Per Avg Match               1.88
# Year                                  2020
# Name: 647, dtype: object
# Country                      Netherlands
# League                        Eredivisie
# Club                               (CSK)
# Player Names               Chidera Ejuke
# Matches_Played                      24.0
# Substitution                         1.0
# Mins                              2147.0
# Goals                                9.0
# Shots                               60.0
# OnTarget                            25.0
# Shots Per Avg Match                 2.65
# On Target Per Avg Match             1.11
# Year                                2020
# Name: 648, dtype: object
# Country                     Netherlands
# League                       Eredivisie
# Club                              (AZA)
# Player Names                Myron Boadu
# Matches_Played                     24.0
# Substitution                        0.0
# Mins                             2099.0
# Goals                              14.0
# Shots                              60.0
# OnTarget                           30.0
# Shots Per Avg Match                2.72
# On Target Per Avg Match            1.36
# Year                               2020
# Name: 649, dtype: object
# Country                            Netherlands
# League                              Eredivisie
# Club                                     (AJA)
# Player Names               Klaas-Jan Huntelaar
# Matches_Played                             6.0
# Substitution                              12.0
# Mins                                     938.0
# Goals                                      NaN
# Shots                                     32.0
# OnTarget                                  17.0
# Shots Per Avg Match                       3.24
# On Target Per Avg Match                   1.72
# Year                                      2020
# Name: 650, dtype: object
# Country                          Netherlands
# League                            Eredivisie
# Club                                   (WIL)
# Player Names               Vangelis Pavlidis
# Matches_Played                          25.0
# Substitution                             0.0
# Mins                                  2265.0
# Goals                                   11.0
# Shots                                   70.0
# OnTarget                                31.0
# Shots Per Avg Match                     2.94
# On Target Per Avg Match                  1.3
# Year                                    2020
# Name: 651, dtype: object
# Country                         Netherlands
# League                           Eredivisie
# Club                                  (EMM)
# Player Names               Michael de Leeuw
# Matches_Played                         26.0
# Substitution                            0.0
# Mins                                 2383.0
# Goals                                   9.0
# Shots                                  51.0
# OnTarget                                NaN
# Shots Per Avg Match                    2.03
# On Target Per Avg Match                0.92
# Year                                   2020
# Name: 652, dtype: object
# Country                      Netherlands
# League                        Eredivisie
# Club                               (PSV)
# Player Names               Donyell Malen
# Matches_Played                      14.0
# Substitution                         0.0
# Mins                              1245.0
# Goals                               11.0
# Shots                               59.0
# OnTarget                            32.0
# Shots Per Avg Match                  4.5
# On Target Per Avg Match             2.44
# Year                                2020
# Name: 653, dtype: object
# Country                     Netherlands
# League                       Eredivisie
# Club                              (RZA)
# Player Names               Haris Vuckic
# Matches_Played                     23.0
# Substitution                        2.0
# Mins                             2194.0
# Goals                               NaN
# Shots                              38.0
# OnTarget                           17.0
# Shots Per Avg Match                1.65
# On Target Per Avg Match            0.74
# Year                               2020
# Name: 654, dtype: object
# Country                     Netherlands
# League                       Eredivisie
# Club                              (UTR)
# Player Names                Gyrano Kerk
# Matches_Played                     24.0
# Substitution                        0.0
# Mins                             2155.0
# Goals                              10.0
# Shots                              50.0
# OnTarget                           18.0
# Shots Per Avg Match                 2.2
# On Target Per Avg Match            0.79
# Year                               2020
# Name: 655, dtype: object
# Country                      Netherlands
# League                        Eredivisie
# Club                               (AJA)
# Player Names               Quincy Promes
# Matches_Played                      18.0
# Substitution                         2.0
# Mins                              1573.0
# Goals                               12.0
# Shots                               56.0
# OnTarget                            30.0
# Shots Per Avg Match                 3.38
# On Target Per Avg Match             1.81
# Year                                2020
# Name: 656, dtype: object
# Country                        Netherlands
# League                          Eredivisie
# Club                                 (PSV)
# Player Names               Denzel Dumfries
# Matches_Played                        25.0
# Substitution                           0.0
# Mins                                2363.0
# Goals                                  7.0
# Shots                                 45.0
# OnTarget                              14.0
# Shots Per Avg Match                   1.81
# On Target Per Avg Match               0.56
# Year                                  2020
# Name: 657, dtype: object
# Country                        Netherlands
# League                          Eredivisie
# Club                                  None
# Player Names               Cyriel Dessers
# Matches_Played                        26.0
# Substitution                           0.0
# Mins                                2461.0
# Goals                                  NaN
# Shots                                 84.0
# OnTarget                              43.0
# Shots Per Avg Match                   3.24
# On Target Per Avg Match               1.66
# Year                                  2020
# Name: 658, dtype: object
# Country                     Netherlands
# League                       Eredivisie
# Club                              (PSV)
# Player Names                 Cody Gakpo
# Matches_Played                     14.0
# Substitution                       11.0
# Mins                             1557.0
# Goals                               7.0
# Shots                              38.0
# OnTarget                           15.0
# Shots Per Avg Match                2.32
# On Target Per Avg Match            0.92
# Year                               2020
# Name: 659, dtype: object

# %%
from transliterate import translit

for index, row in df.iterrows():
    print(row["Mins"])
# Out:
# 1849.0
# 3129.0
# 2940.0
# 2842.0
# 1745.0
# 2634.0
# 1967.0
# 2694.0
# 2354.0
# 2904.0
# 2480.0
# 2340.0
# 2910.0
# 3361.0
# 1392.0
# 1735.0
# 2102.0
# 2984.0
# 1633.0
# 1690.0
# 2567.0
# 2054.0
# 3294.0
# 2648.0
# 2671.0
# 3247.0
# 3276.0
# 2633.0
# 2764.0
# 3188.0
# 3308.0
# 2585.0
# 3194.0
# 3031.0
# 3030.0
# 2737.0
# 2228.0
# 3138.0
# 2033.0
# 3241.0
# 2315.0
# 2673.0
# 2028.0
# 2695.0
# 2449.0
# 2477.0
# 2871.0
# 2420.0
# 2496.0
# 1351.0
# 2772.0
# 2950.0
# 2000.0
# 833.0
# 2894.0
# 1494.0
# 2121.0
# 1895.0
# 3075.0
# 1882.0
# 3385.0
# 3448.0
# 2636.0
# 2938.0
# 3299.0
# 2250.0
# 3101.0
# 3228.0
# 2347.0
# 2327.0
# 3232.0
# 3182.0
# 2444.0
# 3511.0
# 2562.0
# 2493.0
# 2578.0
# 1311.0
# 2174.0
# 2856.0
# 2981.0
# 2757.0
# 2234.0
# 1684.0
# 2448.0
# 2016.0
# 2051.0
# 2670.0
# 2360.0
# 2511.0
# 1786.0
# 3322.0
# 1412.0
# 2423.0
# 3093.0
# 2821.0
# 2143.0
# 2007.0
# 2147.0
# 1834.0
# 2390.0
# 2596.0
# 3053.0
# 1872.0
# 2770.0
# 3008.0
# 2071.0
# 3123.0
# 3168.0
# 2864.0
# 2869.0
# 2163.0
# 2375.0
# 3081.0
# 3555.0
# 2785.0
# 2572.0
# 1630.0
# 3180.0
# 2517.0
# 3359.0
# 3014.0
# 2229.0
# 2407.0
# 2935.0
# 2735.0
# 2864.0
# 2797.0
# 2914.0
# 2854.0
# 2115.0
# 3157.0
# 3491.0
# 3177.0
# 2897.0
# 2799.0
# 3133.0
# 3096.0
# 2244.0
# 2950.0
# 2247.0
# 2507.0
# 2447.0
# 2272.0
# 3062.0
# 1330.0
# 1555.0
# 2353.0
# 2362.0
# 1666.0
# 2596.0
# 2317.0
# 2312.0
# 1879.0
# 1974.0
# 2279.0
# 2626.0
# 2419.0
# 2693.0
# 1480.0
# 1465.0
# 2824.0
# 1224.0
# 1222.0
# 1792.0
# 2278.0
# 1865.0
# 1694.0
# 2847.0
# 2383.0
# 2136.0
# 1751.0
# 2089.0
# 1953.0
# 2933.0
# 2472.0
# 2931.0
# 1547.0
# 2022.0
# 1769.0
# 3072.0
# 3148.0
# 2369.0
# 2569.0
# 3148.0
# 2897.0
# 2131.0
# 2964.0
# 2954.0
# 1999.0
# 2471.0
# 2877.0
# 3300.0
# 3349.0
# 3246.0
# 2849.0
# 2819.0
# 1861.0
# 2975.0
# 3381.0
# 2560.0
# 3064.0
# 2191.0
# 2857.0
# 3046.0
# 3533.0
# 3269.0
# 2125.0
# 2741.0
# 3196.0
# 2075.0
# 2262.0
# 3641.0
# 2903.0
# 2388.0
# 2416.0
# 2213.0
# 2430.0
# 2314.0
# 3147.0
# 2527.0
# 2613.0
# 3033.0
# 2353.0
# 2075.0
# 2602.0
# 1385.0
# 2661.0
# 1312.0
# 2582.0
# 1781.0
# 2945.0
# 3061.0
# 1965.0
# 2432.0
# 2587.0
# 2312.0
# 2975.0
# 3090.0
# 2556.0
# 2418.0
# 2719.0
# 3533.0
# 1434.0
# 3190.0
# 1911.0
# 1517.0
# 1747.0
# 2541.0
# 3446.0
# 2741.0
# 2488.0
# 3000.0
# 2699.0
# 3115.0
# 3263.0
# 2154.0
# 2900.0
# 2154.0
# 2698.0
# 3651.0
# 3143.0
# 3233.0
# 3417.0
# 2569.0
# 2684.0
# 2822.0
# 3236.0
# 2714.0
# 2152.0
# 2580.0
# 2566.0
# 3115.0
# 2905.0
# 3302.0
# 2930.0
# 2886.0
# 3099.0
# 2670.0
# 3285.0
# 2962.0
# 2175.0
# 2487.0
# 1367.0
# 2808.0
# 3236.0
# 3192.0
# 2850.0
# 2188.0
# 1081.0
# 2575.0
# 4177.0
# 1689.0
# 3931.0
# 2636.0
# 3231.0
# 1623.0
# 2595.0
# 2153.0
# 3140.0
# 3277.0
# 3050.0
# 2998.0
# nan
# 2464.0
# 2420.0
# 2740.0
# 2734.0
# 2657.0
# 1742.0
# 2717.0
# 1555.0
# 3104.0
# 2905.0
# 2521.0
# 2346.0
# 1834.0
# 3128.0
# nan
# 2398.0
# 2126.0
# 3207.0
# 2990.0
# 2428.0
# 2923.0
# 3247.0
# 2171.0
# 2831.0
# 2673.0
# 2222.0
# 3034.0
# 2248.0
# 1611.0
# 3067.0
# 3100.0
# 2929.0
# 2513.0
# 2436.0
# 2923.0
# 3474.0
# 631.0
# 1867.0
# 396.0
# 2451.0
# 2732.0
# 780.0
# 2495.0
# 575.0
# 624.0
# 2471.0
# 605.0
# 591.0
# 645.0
# 2537.0
# 1928.0
# 642.0
# 2054.0
# 2570.0
# 736.0
# 280.0
# 2633.0
# 337.0
# 644.0
# 1416.0
# 1656.0
# 530.0
# 2312.0
# 2981.0
# 2399.0
# 2747.0
# 1732.0
# 646.0
# 714.0
# 622.0
# 1749.0
# 356.0
# 2750.0
# 509.0
# 567.0
# 1684.0
# 1870.0
# 3156.0
# 3125.0
# 3075.0
# 3263.0
# 3127.0
# 2654.0
# 3394.0
# 1786.0
# 1637.0
# 3115.0
# 3371.0
# 2627.0
# 2143.0
# 2581.0
# 1370.0
# 2413.0
# 1906.0
# 1514.0
# 3214.0
# 2387.0
# 2744.0
# 2893.0
# 1502.0
# 1561.0
# 2586.0
# 2296.0
# 2592.0
# 2783.0
# 1694.0
# 2846.0
# 1116.0
# 2108.0
# 2159.0
# 2595.0
# 1518.0
# 2718.0
# 2216.0
# 2813.0
# 2252.0
# 1396.0
# 2057.0
# 1353.0
# 1077.0
# 1994.0
# 2276.0
# 2168.0
# 2409.0
# 2214.0
# 2321.0
# 2163.0
# 1378.0
# 1325.0
# 2173.0
# 2030.0
# 2106.0
# 2358.0
# 2344.0
# 1611.0
# 2434.0
# 2849.0
# 3445.0
# 2984.0
# 3271.0
# 2836.0
# 2933.0
# 2616.0
# 2788.0
# 2130.0
# 2663.0
# 2826.0
# 3045.0
# 2209.0
# 3009.0
# 3392.0
# 2801.0
# 3289.0
# 3087.0
# 2380.0
# 1566.0
# 3313.0
# 2901.0
# 2193.0
# 1836.0
# 3149.0
# 1929.0
# 1917.0
# 2498.0
# 2524.0
# 3180.0
# 2648.0
# 3233.0
# 3049.0
# 2716.0
# 2650.0
# 2822.0
# 2062.0
# 2883.0
# 3181.0
# 1661.0
# 575.0
# 574.0
# 719.0
# 569.0
# 896.0
# 723.0
# 775.0
# 827.0
# 768.0
# 725.0
# 524.0
# 490.0
# 680.0
# 824.0
# 927.0
# 916.0
# 834.0
# 853.0
# 506.0
# 911.0
# 2247.0
# 1430.0
# 1872.0
# 1190.0
# 1816.0
# 2014.0
# 1626.0
# 1482.0
# nan
# 2106.0
# 1726.0
# nan
# 1927.0
# 2216.0
# 1701.0
# 2063.0
# 1195.0
# 1189.0
# 1864.0
# nan
# 465.0
# 691.0
# 741.0
# 599.0
# 629.0
# 736.0
# 589.0
# 637.0
# 824.0
# 641.0
# 387.0
# 693.0
# 758.0
# 566.0
# 634.0
# 1056.0
# 790.0
# 501.0
# 451.0
# 822.0
# 849.0
# 567.0
# 831.0
# 643.0
# 754.0
# 755.0
# 664.0
# 766.0
# 825.0
# 769.0
# 669.0
# 656.0
# 264.0
# 397.0
# 580.0
# 616.0
# 571.0
# 694.0
# 557.0
# 568.0
# 561.0
# 732.0
# 626.0
# 778.0
# 834.0
# 709.0
# 822.0
# 669.0
# 802.0
# 547.0
# 723.0
# 481.0
# 293.0
# 567.0
# 841.0
# 683.0
# 493.0
# 608.0
# 857.0
# 672.0
# 990.0
# 644.0
# 822.0
# 709.0
# 902.0
# 903.0
# 482.0
# 772.0
# 454.0
# 452.0
# 627.0
# 879.0
# 835.0
# 903.0
# 1061.0
# 1008.0
# 610.0
# 669.0
# 903.0
# 786.0
# 960.0
# 809.0
# 940.0
# 876.0
# 835.0
# 530.0
# 779.0
# 872.0
# 872.0
# 845.0
# 898.0
# 831.0
# 780.0
# 956.0
# 662.0
# 786.0
# 872.0
# 785.0
# 612.0
# 861.0
# 1588.0
# 1348.0
# 1662.0
# 914.0
# 1235.0
# 1336.0
# 1733.0
# 1397.0
# 1063.0
# 1709.0
# 1434.0
# 1412.0
# nan
# 1829.0
# 861.0
# 1208.0
# 1657.0
# 1937.0
# 1207.0
# 1639.0
# 2023.0
# 2336.0
# 1933.0
# 2256.0
# 2157.0
# 2047.0
# 2287.0
# 2226.0
# 2147.0
# 2099.0
# 938.0
# 2265.0
# 2383.0
# 1245.0
# 2194.0
# 2155.0
# 1573.0
# 2363.0
# 2461.0
# 1557.0

# %% [markdown]
# ## Creating New Columns
#
# And sometimes we would like to create new columns to progress our analyses.
#
# We accomplish this using syntax similar to Python dictionaries, where we simply assign a value to a new key.

# %%
diction = {}

diction["Hello"] = "Goodbye"

print(diction)
# Out:
# {'Hello': 'Goodbye'}

# %% [markdown]
# Let’s say we want to compute the ratio of goals per shots.

# %%
df["Goals_Ratio"] = df["Goals"] / df["Shots"]

df.head()
# Out:
#   Country   League   Club       Player Names  Matches_Played  Substitution  \
# 0   Spain  La Liga  (BET)    Juanmi Callejon            19.0          16.0
# 1   Spain  La Liga  (BAR)  Antoine Griezmann            36.0           0.0
# 2   Spain  La Liga  (ATL)        Luis Suarez            34.0           1.0
# 3   Spain  La Liga  (CAR)       Ruben Castro            32.0           3.0
# 4   Spain  La Liga  (VAL)      Kevin Gameiro            21.0          10.0
#
#      Mins  Goals  Shots  OnTarget  Shots Per Avg Match  \
# 0  1849.0   11.0   48.0      20.0                 2.47
# 1  3129.0   16.0   88.0      41.0                 2.67
# 2  2940.0   28.0  120.0      57.0                 3.88
# 3  2842.0    NaN  117.0      42.0                 3.91
# 4  1745.0   13.0   50.0      23.0                 2.72
#
#    On Target Per Avg Match  Year  Goals_Ratio
# 0                     1.03  2016            1
# 1                     1.24  2016            1
# 2                     1.84  2016            1
# 3                     1.40  2016            1
# 4                     1.25  2016            1

# %% [markdown]
# ## Database Concepts
#
# Before we explore SQL and its syntax, we must be familiar with a couple of concepts & terms
# * DBMS (Database Management System)
# * Database
# * Relational Database
# * Keys
# * Set Theory

# %% [markdown]
# ## DBMS
#
# DBMS (Database Management System) is a software tool for storing and managing large amounts of data.
#
# A database server is a specific installation of a DBMS.
# Meanwhile, a database is simply a collection of data, often stored in a server.
#
# Properties of a DBMS
#
# Allow users to Read/Write/Update using a query language
# Allow multiple users to manipulate data without failure
# Store massive amounts of data.
# Backups

# %% [markdown]
# ## Databases
#
# A set of rules that describe how data is stored.
#
# What kinds of data does it accept? (Strings, numbers, booleans)
#
# Database schema (or data model) describes what types of data are valid to store
#
# Database instance is the actual data that exists inside the database
#
# We will be working with relational databases, which are essentially dataframes.

# %% [markdown]
# ## Keys
#
# A key is some data value that maps to some unique assortment of data

# %% [markdown]
# ## SQL Basics
#
# For the next queries, we will be working on the website: https://onecompiler.com/postgresql/
#
# To create a database, copy and paste the following query:
#
# We use the syntax `CREATE TABLE <NAME>(attribute1 datatyp1, attribute2 datatype2)`

# %%
create table bakers(
      baker        varchar(10) primary key
      , fullname   varchar(100)
      , age        int
      , occupation varchar(100)
      , hometown   varchar(100)
);

# %%
insert into bakers values('Antony','Antony Amourdoux',30,'Banker','London');
insert into bakers values('Briony','Briony Williams',33 ,'Full-time parent','Bristol');
insert into bakers values('Dan','Dan Beasley-Harling',36 ,'Full-time parent','London');
insert into bakers values('Imelda','Imelda McCarron',33 ,'Countryside recreation officer','County Tyrone');
insert into bakers values('Jon','Jon Jenkins',47 ,'Blood courier','Newport');
insert into bakers values('Karen','Karen Wright',60 ,'In-store sampling assistant','Wakefield');
insert into bakers values('Kim-Joy','Kim-Joy Hewlett',27 ,'Mental health specialist','Leeds');
insert into bakers values('Luke','Luke Thompson',30 ,'Civil servant/house and techno DJ','Sheffield');
insert into bakers values('Manon','Manon Lagrève',26 ,'Software project manager','London');
insert into bakers values('Rahul','Rahul Mandal',30 ,'Research scientist','Rotherham');
insert into bakers values('Ruby','Ruby Bhogal',29 ,'Project manager','London');
insert into bakers values('Terry','Terry Hartill',56 ,'Retired air steward','West Midlands');

# %% [markdown]
# ## Queries
#
# Firstly, we will review how to create queries for data. Essentially, how to request data.
# The general format goes:
#
# 				SELECT ...
#                 FROM ...
#                 WHERE …;
#
# Let’s say we want to select the names of bakers that are younger than 40.

# %%
SELECT baker, age
FROM bakers
WHERE age < 40;

# %% [markdown]
# We can get more information by indicating more attributes:

# %%
SELECT baker, age
FROM bakers
WHERE age < 40;

# %% [markdown]
# We can combine logical statements using “and” or “or”
#
# Let’s say we want to select bakers only from London:

# %%
SELECT baker, age
FROM bakers
WHERE age < 40 and hometown = 'London';
