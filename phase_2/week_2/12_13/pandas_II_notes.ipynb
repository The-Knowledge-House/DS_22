# %% [markdown]
# ## Individual Coding Exercise
#
# Create a Python function called `check` that will check if the number of "X's" in a string called `word` equals the number of "O's".
#
# Example 1:
# ```
# Input -> "XOOX"
# Return -> True
# Reason -> There are 2 X's and 2 O's.
# ```
#
# Example 2:
# ```
# Input -> "XXOOOX"
# Return -> True
# Reason -> There are 3 X's and 3 O's.
# ```
#
# Example 3:
# ```
# Input -> "XOX"
# Return -> False
# Reason -> There are 2 X's and 1 O.
# ```
#
# Example 4:
# ```
# Input -> "XXOOOOXX"
# Return -> True
# Reason -> There are 4 X's and 4 O.
# ```
#
# Keep time complexity in mind after creating an initial solution

# %%
word1 = "XOOX"
word2 = "XXOOOX"
word3 = "XOX"
word4 = "XXOOOOXX"

# write code here
def check(word):
    pass


# this should print out true
print(check(word1) == True)
print(check(word2) == True)
print(check(word3) == False)
print(check(word4) == True)

# %% [markdown]
# ## Additional Challenge
#
# Another requirement we can check is if a string has an equal amount of X's and O's and if its a palindrome. That is, reading it forwards results in the same string as reading it backwards.
#
# Create a Python function called `check2` that will check if the number of "X's" in a string called `word` equals the number of "O's" AND it is a palindrome.
#
# This changes a few test-cases. For example while `word2` does have an equal amount of X's and O's it is not a palindrome, so therefore we return false.
#
# Example 1:
# ```
# Input -> "XOOX"
# Return -> True
# Reason -> There are 2 X's and 2 O's, and it is a palindrome.
# ```
#
# Example 2:
# ```
# Input -> "XXOOOX"
# Return -> False
# Reason -> There are 3 X's and 3 O's, but it is not a palindrome.
# ```
#
# Example 3:
# ```
# Input -> "XOX"
# Return -> False
# Reason -> There are 2 X's and 1 O.
# ```
#
# Example 4:
# ```
# Input -> "XXOOOOXX"
# Return -> True
# Reason -> There are 4 X's and 4 O, and it is a palindrome.
# ```
#
# Keep time complexity in mind after creating an initial solution.

# %%
word1 = "XOOX"
word2 = "XXOOOX"
word3 = "XOX"
word4 = "XXOOOOXX"

# write code here
def check2(word):
    pass

# these all should print out true
print(check2(word1) == True)
print(check2(word2) == False)
print(check2(word3) == False)
print(check2(word4) == True)
# Out:
# True
# True
# True
# True

# %% [markdown]
# ## Dataset
#
# Find Netflix movie rankings dataset
# * Located in `data` folder of `week_2`
# * Labeled imdb_processed.csv
#
# Specifically, we will focus on the following analyses:
# * Is the count of movies increasing or decreasing over the years?
# * Did ratings of movies increase or decrease from 92 - 94?

# %%
import pandas as pd

df = pd.read_csv("../data/imdb_processed.csv", index_col=0)
df.head()
# Out:
#                                                    title  year  \
# index
# 0                                        Dinosaur Planet  2003
# 1                                      Get Up and Dance!  1994
# 2                                                  8 Man  1992
# 3                           What the #$*! Do We (K)now!?  2004
# 4      Class of Nuke 'Em High Part II: Subhumanoid Me...  1991
#
#                  kind                                              genre  \
# index
# 0      tv mini series             ['Documentary', 'Animation', 'Family']
# 1         video movie                                         ['Family']
# 2               movie                               ['Action', 'Sci-Fi']
# 3               movie  ['Documentary', 'Comedy', 'Drama', 'Fantasy', ...
# 4               movie                     ['Comedy', 'Horror', 'Sci-Fi']
#
#        rating     vote            country                          language  \
# index
# ...

# %% [markdown]
# ## Filtering
#
# To start we must “filter” our data to only include rows that describe “movies.” We’re throwing nuance out the window and omitting “tv movies” or “video movies”
#
# Namely, we can create an array of boolean values (T or F) by checking for the equality or inequality in a certain column.
#
# Firstly, what is the name of the feature that describes if something is a movie or a tv-show or something else.
#
# Next, we will simply use our equality (==) operator to check if a row in the “kind” column describes a “movie”.
#
# By writing this filter within our square brackets of `df` we get a new dataframe that describes rows where our boolean is True. AKA where we have a row where the column of “kind” is movie

# %%
df["kind"] == "movie"
# Out:
# index
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 8446     True
# 8447    False
# 8448    False
# 8449     True
# 8450     True
# Name: kind, Length: 8451, dtype: bool

# %%
movies = df[df["kind"] == "tv series"]
movies
# Out:
#                                                    title  year   kind  \
# index
# 2                                                  8 Man  1992  movie
# 3                           What the #$*! Do We (K)now!?  2004  movie
# 4      Class of Nuke 'Em High Part II: Subhumanoid Me...  1991  movie
# 9                                        Seeta Aur Geeta  1972  movie
# 17                                 Zatoichi's Conspiracy  1973  movie
# ...                                                  ...   ...    ...
# 8444                                           Interiors  1978  movie
# 8445                                 Shakespeare in Love  1998  movie
# 8446                                 All Monsters Attack  1969  movie
# 8449                                         The Company  2003  movie
# 8450                                            Predator  1987  movie
#
#                                                    genre  rating      vote  \
# index
# ...

# %%
movies["year"] == 1992
# Out:
# index
# 2        True
# 3       False
# 4       False
# 9       False
# 17      False
#         ...
# 8444    False
# 8445    False
# 8446    False
# 8449    False
# 8450    False
# Name: year, Length: 4995, dtype: bool

# %%
at92 = movies[movies["year"] == 1992]
at93 = movies[movies["year"] == 1993]
at94 = movies[movies["year"] == 1994]

# %%
post92 = movies[(movies["year"] > 1992) & (movies["rating"] > 9.0)]
# Out:
#                               title  year   kind      genre  rating  \
# index
# 563        The Shawshank Redemption  1994  movie  ['Drama']     9.3
# 604    Yanni: Live at the Acropolis  1994  movie  ['Music']     9.3
# 2251            Pride 25: Body Blow  2003  movie  ['Sport']     9.3
# 5022       The Shawshank Redemption  1994  movie  ['Drama']     9.3
#
#             vote                              country  \
# index
# 563    2461873.0                    ['United States']
# 604        410.0  ['United States', 'United Kingdom']
# 2251         8.0                            ['Japan']
# 5022   2462087.0                    ['United States']
#
#                       language  \
# index
# 563                ['English']
# 604                ['English']
# 2251   ['English', 'Japanese']
# 5022               ['English']
#
#                                                     cast            director  \
# index
# ...

# %% [markdown]
# ## Cleaning
#
# We managed to create our dataframe that only include movies in the `movies` DataFrame object
#
# As we might have noticed, there are missing values in our dataframe.
#
# Missing values could potentially bias our results, or block certain methods from running.
#
# We will talk about more formal methods of data cleaning throughout this phase, but for now, let us simply delete any row that contains a null value.
#
# We could potentially “filter” our rows using our filters.
#
# Filtering should be reserved for DataFrame subsetting. We will use built-in functions.
#
# Conceptually however, we also want to filter out data that only has more than 30 votes (Central Limit Theorem)
#
# This is to avoid the possibility that only one loyal fan rated a movie 10/10 when in reality most people will find this film unpalatable.
#
# How can we achieve this?

# %%
movies.dropna(inplace=True)

movies_valid = movies[movies["vote"] > 30]
movies_valid
# Out:
# C:\Users\saidmf\AppData\Local\Temp\ipykernel_18240\366306571.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies.dropna(inplace=True)
#                                                    title  year   kind  \
# index
# 3                           What the #$*! Do We (K)now!?  2004  movie
# 4      Class of Nuke 'Em High Part II: Subhumanoid Me...  1991  movie
# 9                                        Seeta Aur Geeta  1972  movie
# 17                                 Zatoichi's Conspiracy  1973  movie
# 20                                          TerrorVision  1986  movie
# ...                                                  ...   ...    ...
# 7260                                   À Nous la Liberté  1931  movie
# 7261                                               Shade  2003  movie
# ...

# %% [markdown]
# ## Builtins
#
# Now that have our dataframe prepared & cleaned. How can I answer the following question?
# Is the count of movies increasing or decreasing?
#
# We will use our built pandas methods, namely `value_counts(“column”)`
#
# This function works by counting how many unique instances it views in the specified column, and creates a new dataframe detailing this.
#
# You’ll notice that our years is not sorted by default, so we will call another builtin function called `sort_index`which sorts our dataframe according to its index.
#
# Just observing this dataframe is not sufficient to visualize our differences, so we will actually be using a builtin `plot()` method that will also generate a matplotlib line plot!

# %% [markdown]
# While we’ve analyzed our DataFrame and answered our first pseudo-research-question, let’s move onto:
# Did ratings of movies increase or decrease from 92 - 94?
# Let’s bring back our DataFrames `at92`, `at93`, and `at94` and see if can get their means using the “mean()” function

# %%
year_counts = movies.value_counts("year").sort_index()
year_counts.plot()
# Out:
# year
# 2001    329
# 2002    323
# 2003    312
# 2000    286
# 2004    269
#        ...
# 1923      1
# 1919      1
# 1916      1
# 1914      1
# 1913      1
# Length: 91, dtype: int64

# %%
at92.mean()
# Out:
# C:\Users\saidmf\AppData\Local\Temp\ipykernel_18240\2720093447.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   at92.mean()
# year        1992.000000
# rating         6.625532
# vote       23466.723404
# runtime      100.368421
# dtype: float64

# %%
at92["rating"].mean()
# Out:
# 6.625531914893619

# %%
at93["rating"].mean()
# Out:
# 6.546218487394958

# %%
at94["rating"].mean()
# Out:
# 6.627272727272728
