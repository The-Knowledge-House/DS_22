# %% [markdown]
# ## Loop task 1

# %% [markdown]
# ## Loop task 2

# %% [markdown]
# ## Loop task 3

# %% [markdown]
# ## Nested Conditionals 1

# %% [markdown]
# ## Nested Conditionals 2

# %% [markdown]
# ## Bonus 1

# %% [markdown]
# ## Bonus 2
